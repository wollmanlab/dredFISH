# %%
import numpy as np
import pandas as pd
import glob
import os
import json
import anndata
import time

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

from dredFISH.Analysis.__init__plots import *
from dredFISH.Analysis import basicu

# %%
f = '/bigstore/binfo/mouse/Brain/DRedFISH/Allen_V3_Reference/10X/probe_constraints.npy'
cnstrnts = np.load(f)
cnstrnts
# Out:
# array([ 36, 250,  59, ..., 199, 124,  92])

# %%
fig, ax = plt.subplots()
ax.plot(np.sort(cnstrnts))
ax.set_xlabel('Gene')
ax.set_ylabel('Num. available probe sites')
# Out:
# Text(0, 0.5, 'Num. available probe sites')
