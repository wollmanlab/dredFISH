# %%
import json
import numpy as np
import glob
import os

import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn

import importlib

from dredFISH.Analysis.__init__plots import *
from dredFISH.Analysis import basicu 

from dredFISH.Design.model_v1_gene_celltype import CellTypeNet
from dredFISH.Design import data_loader_scrna 
importlib.reload(data_loader_scrna)
# Out:
# <module 'dredFISH.Design.data_loader_scrna' from '/bigstore/GeneralStorage/fangming/projects/dredfish/packages/dredFISH/dredFISH/Design/data_loader_scrna.py'>

# %%
rootdat_dir = '/bigstore/GeneralStorage/fangming/projects/dredfish/res_nn/' #02_reduced_class_longiter/'
# !ls $rootdat_dir

nrcn = 1
lr = 0.1
dat_dir = rootdat_dir + f'10-v8-2-tenx-gene140_lmd01.00e+00_nbit70_nrcn{nrcn}_lr{lr}'
# + f'10-v5-nonoise-smrt-gene140_lmd01.00e+00_nbit70_nrcn1_lr0.1'
print(dat_dir)
print(os.path.isdir(dat_dir))
# Out:
# 00_test_recon
# 01_test_recon
# 02-2_reduced_class_longiter
# 02_reduced_class
# 03-1_gpu
# 03-2_cpu
# 04-1_gpu
# 04-2_cpu
# 05-1_drprt0.0
# 05-1_drprt0.1
# 05-1_drprt0.2
# 05-1_drprt0.3
# 05-1_drprt0.4
# 05-1_drprt0.5
# 05-1_drprt0.6
# 05-1_drprt0.7
# 05-1_drprt0.8
# 05-1_drprt0.9
# 06-gene140
# 06-gene140_lmd01.00e-01
# 06-gene140_lmd01.00e+01
# 06-gene140_lmd01.00e-03
# 06-gene140_lmd01.00e+03
# 06-gene140_lmd01.00e-05
# 06-gene140_lmd01.00e+05
# 06-v3-simple-gene140_1.00e+00
# 06-v3-simple-gene140_1.00e-05
# 06-v3-simple-gene140_1.00e+05
# 06-v4-gene140_lmd01.00e+00
# 06-v4-gene140_lmd01.00e-05
# 06-v4-gene140_lmd01.00e+05
# 06-v5-gene140_lmd01.00e+05
# 06-v6-simple-gene140_lmd01.00e+05_nbit100
# 06-v6-simple-gene140_lmd01.00e+05_nbit50
# 06-v6-simple-gene140_lmd01.00e+05_nbit70
# 06-v7-simple-gene140_lmd01.00e+05_nbit70_nrcn1
# 06-v7-simple-gene140_lmd01.00e+05_nbit70_nrcn1_lr0.001
# 06-v7-simple-gene140_lmd01.00e+05_nbit70_nrcn1_lr0.01
# 06-v7-simple-gene140_lmd01.00e+05_nbit70_nrcn1_lr0.1
# 06-v7-simple-gene140_lmd01.00e+05_nbit70_nrcn1_lr1
# 06-v7-simple-gene140_lmd01.00e+05_nbit70_nrcn1_lr1e+01
# 06-v7-simple-gene140_lmd01.00e+05_nbit70_nrcn1_lr1e+02
# 06-v7-simple-gene140_lmd01.00e+05_nbit70_nrcn2
# 06-v7-simple-gene140_lmd01.00e+05_nbit70_nrcn3
# 06-v8-smrt-simple-gene140_lmd01.00e+05_nbit70_nrcn1_lr0.1
# 06-v8-tenx-simple-gene140_lmd01.00e+05_nbit70_nrcn1_lr0.1
# 07-crse
# 07-fine
# 07-v2-crse-drprt0.0
# 07-v2-crse-drprt0.1
# 07-v2-crse-drprt0.2
# 07-v2-crse-drprt0.3
# 07-v2-crse-drprt0.4
# 07-v2-crse-drprt0.5
# 07-v2-crse-drprt0.6
# 07-v2-crse-drprt0.7
# 07-v2-crse-drprt0.8
# 07-v2-crse-drprt0.9
# 07-v2-fine-drprt0.0
# 07-v2-fine-drprt0.1
# 07-v2-fine-drprt0.2
# 07-v2-fine-drprt0.3
# 07-v2-fine-drprt0.4
# 07-v2-fine-drprt0.5
# 07-v2-fine-drprt0.6
# 07-v2-fine-drprt0.7
# 07-v2-fine-drprt0.8
# 07-v2-fine-drprt0.9
# 09-test-newdatastream-smrt-simple-gene140_lmd01.00e+05_nbit70_nrcn1_lr0.1
# 09-v2-gsub-smrt-simple-gene140_lmd01.00e+00_nbit70_nrcn1_lr0.1
# 09-v3-gene-celltype_lmd01.00e+00_nbit70_nrcn1_lr0.1
# 09-v3-gene-celltype_lmd01.00e+00_nbit70_nrcn1_lr0.1-lag2
# 10-v1-smrt-gene140_lmd01.00e+00_nbit70_nrcn1_lr0.01
# 10-v2-smrt-gene140_lmd01.00e+00_nbit70_nrcn1_lr0.1
# 10-v3-smrt-gene140_lmd01.00e+00_nbit70_nrcn1_lr0.1
# 10-v4-smrt-gene140_lmd01.00e+00_nbit70_nrcn1_lr0.1
# 10-v5-nonoise-smrt-gene140_lmd01.00e+00_nbit70_nrcn1_lr0.1
# 10-v6-smrt-gene140_lmd01.00e+00_nbit70_nrcn1_lr0.1
# 10-v7-l2-smrt-gene140_lmd01.00e+00_nbit70_nrcn2_lr0.01
# 10-v8-2-tenx-gene140_lmd01.00e+00_nbit70_nrcn1_lr0.1
# 10-v8-tenx-gene140_lmd01.00e+00_nbit70_nrcn1_lr0.1
# 10-v9-l2-lag2-smrt-gene140_lmd01.00e+00_nbit70_nrcn2_lr0.001
# 10-v9-l2-smrt-gene140_lmd01.00e+00_nbit70_nrcn2_lr0.001
# /bigstore/GeneralStorage/fangming/projects/dredfish/res_nn/10-v8-2-tenx-gene140_lmd01.00e+00_nbit70_nrcn1_lr0.1
# True

# %% [markdown]
# # outputs
# - embmat - a (ncell, nbit (24)) matrix
# - model - a pytorch format
# - results -- some summary statistics
#
# - meta (what are these parameters?)
#     - max-half_nrml-90000.0-1.27E+05-24-0-2.60E-09-0.01-1.0
#     - max-half_nrml-90000.0-1.32E+05-24-0-3.40E-09-0.01-1.0

# %%
# !ls $dat_dir
# Out:
# 'embmat=xxx-xxx-90000.0-xxx-70-0-xxx-xxx-xxx.json'
# 'model=xxx-xxx-90000.0-xxx-70-0-xxx-xxx-xxx.pt'
# 'result=xxx-xxx-90000.0-xxx-70-0-xxx-xxx-xxx.json'

# %% [markdown]
# # the results (statistics)

# %%
f = glob.glob(os.path.join(dat_dir, 'result*'))[0]
print(f)

with open(f, 'r') as fh:
    res = json.load(fh)
    # res = np.array(res)
    # print(res.shape)
list(res.keys())
# list(res['1'].keys())
# Out:
# /bigstore/GeneralStorage/fangming/projects/dredfish/res_nn/10-v8-2-tenx-gene140_lmd01.00e+00_nbit70_nrcn1_lr0.1/result=xxx-xxx-90000.0-xxx-70-0-xxx-xxx-xxx.json
# ['1', '2', '3']

# %%
_x = []
_y1 = []
_y2 = []
_y3 = []
_y4 = []

_y5 = []
_y6 = []

_y7 = []
_y8 = []

_y9 = []
_y10 = []
for _iter in res.keys():
    _x.append(_iter)
#     _y1.append(np.mean([val for key, val in res[_iter]['smrt_crse_acc'].items()]))
#     _y2.append(np.mean([val for key, val in res[_iter]['tenx_crse_acc'].items()]))
    # _y3.append(np.mean([val for key, val in res[_iter]['smrt_fine_acc'].items()]))
    _y3.append(res[_iter]['0']['fine_acc'])
#     _y4.append(np.mean([val for key, val in res[_iter]['tenx_fine_acc'].items()]))
    
#     _y5.append(res[_iter]['dsc_lss'])
#     _y6.append(res[_iter]['row_cnst'])
    
    # _y7.append(np.mean([val for key, val in res[_iter]['smrt_mrgn_lss'].items()]))
    # _y8.append(np.mean([val for key, val in res[_iter]['tenx_mrgn_lss'].items()]))
    
    _y9.append(res[_iter]['0']['rcn_lss'])
    # _y10.append(np.mean([val for key, val in res[_iter]['tenx_rcn_lss'].items()]))

_x = np.array(_x).astype(int)

# %%
# fig, ax = plt.subplots()
# ax.plot(_x, _y1, '-o', color='k', label='SMART-seq L3')
# ax.plot(_x, _y2, '-o', color='C1', label='10X L3' )
# ax.plot(_x, _y3, '-s', color='k', label='SMART-seq L5')
# ax.plot(_x, _y4, '-s', color='C1', label='10X L5' )
# ax.set_xlabel('Iteration')
# ax.set_ylabel('Classification accuracy\n(validation set)')
# ax.legend(bbox_to_anchor=(1,1))
# sns.despine(ax=ax)
# # powerplots.savefig_autodate(fig, os.path.join(fig_dir, "NN_classification_acc.pdf"))
# plt.show()

# %%
fig, axs = plt.subplots(2,1,figsize=(1*8,2*5), sharex=True)
ax = axs[0]
ax.plot(_x, _y9, '-')
ax.set_title('10X')
ax.set_xlabel('Epochs')
ax.set_ylabel('MSE recon\n(140 genes log expression)')
ax.set_yscale('log')
ax.set_ylim(ymin=1e-1)

ax = axs[1]
ax.plot(_x, _y9, '-')
# ax.set_title('SMART-seq')
ax.set_xlabel('Epochs')
# ax.set_ylabel('MSE recon\n(140 genes log expression)')
# ax.set_yscale('log')
# ax.set_ylim(ymin=1e-1)
# ax.set_ylim([0,2])
# ax.set_xlim([0,300])

plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize=(1*8,1*5))
# ax = axs[0]
ax.plot(_x, _y3, '-')
ax.set_title('10X')
ax.set_xlabel('Epochs')
ax.set_ylabel('Classification accuracy')
ax.set_ylim([-0.05,1.05])


# ax = axs[1]
# ax.plot(_x, _y10, '-')
# ax.set_title('10x')

plt.show()

# %%
def get_mse_torch(tnsr_true, tnsr_pred=[]):
    """Mean (over rows) squared error
    if no pred, returns the variance.
    """
    if len(tnsr_pred):
        mse = (tnsr_true - tnsr_pred).square().mean(axis=0)
    else:
        mse = (tnsr_true - tnsr_true.mean(axis=0)).square().mean(axis=0)
    return mse
        
def get_r2_torch(tnsr_true, tnsr_pred, zero_tol=1e-10):
    """
    """
    mse = get_mse_torch(tnsr_true, tnsr_pred)
    var = get_mse_torch(tnsr_true)
    r2 = 1-mse/torch.clamp(var, min=zero_tol)
    return r2

# device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device = torch.device('cpu')
print(device)
# Out:
# cpu

# %%
# prep the model
f = glob.glob(os.path.join(dat_dir, 'model*'))[0]
print(f)

reduction, cnst, mxpr, min_pos, n_bit, drprt, lmd1, lmd2, lmd3 = (os.path.basename(f)
                                                                        [len('model='):-len('.pt')]
                                                                        .replace('E-', 'expn').split('-')
                                                                 )
lmd0 = 1
mxpr = np.float64(mxpr)
# min_pos = np.float64(min_pos)
n_bit = int(n_bit)
drprt = np.float64(drprt)
# lmd1 = np.float64(lmd1.replace('expn', 'E-'))
# lmd2 = np.float64(lmd2)
# lmd3 = np.float64(lmd3)
reduction, cnst, mxpr, min_pos, n_bit, drprt, lmd1, lmd2, lmd3
# Out:
# /bigstore/GeneralStorage/fangming/projects/dredfish/res_nn/10-v8-2-tenx-gene140_lmd01.00e+00_nbit70_nrcn1_lr0.1/model=xxx-xxx-90000.0-xxx-70-0-xxx-xxx-xxx.pt
# ('xxx', 'xxx', 90000.0, 'xxx', 70, 0.0, 'xxx', 'xxx', 'xxx')

# %%
# %%time
# test
trn_dataloader = data_loader_scrna.load_Allen_data(
    datasetkey='tenx_trn', 
    keyX='counts', keyY='l3_code', keyYcat='l3_cat', 
    batch_size=64,
)
tst_dataloader = data_loader_scrna.load_Allen_data(
    datasetkey='tenx_tst', 
    keyX='counts', keyY='l3_code', keyYcat='l3_cat', 
    batch_size=500,
)
gsubidx = torch.load(
    os.path.join('/bigstore/GeneralStorage/fangming/projects/dredfish/data/', 'rna', 'gidx_sub140_tenx_v1.pt')
)
# Out:
# CPU times: user 8.14 ms, sys: 361 µs, total: 8.5 ms
# Wall time: 14 ms

# %%
# %%time
n_gns = trn_dataloader.dataset.X.shape[1] # number of genes
n_cat = len(trn_dataloader.dataset.Ycat) # number of clusters
n_rcn_layers = nrcn

model= CellTypeNet(n_gns=     n_gns,                      
                   n_cat=     n_cat,                      
                   gsubidx= gsubidx,
                   n_rcn_layers=n_rcn_layers,
                   n_bit=     n_bit,                      # fixed
                   mxpr=      mxpr,
                   drprt=     0,
                   lmd0=      lmd0,
                  )
model.load_state_dict(torch.load(f, map_location=device))
model.to(device)
# model.eval()
# Out:
# CPU times: user 138 ms, sys: 29.3 ms, total: 167 ms
# Wall time: 90.8 ms
# CellTypeNet(
#   (enc): Embedding(31053, 70)
#   (dcd): Embedding(70, 42)
#   (rcn): Sequential(
#     (0): Linear(in_features=70, out_features=140, bias=True)
#     (1): ReLU()
#   )
#   (drp): Dropout(p=0, inplace=False)
#   (nrm): InstNrmSimple()
# )

# %%
model.eval()

# evaluate
i = 0
with torch.no_grad():
    # validation dataset
    tenx_ftrs, tenx_clsts = next(iter(tst_dataloader))
    tenx_ftrs= tenx_ftrs.float().to(device)
    tenx_ftrs_gsub= (tenx_ftrs[:,gsubidx]+1).log() # log(x+1) norm

    tenx_fine, tenx_ftrs_rcn, tenx_emb, = model.forward(tenx_ftrs, rnd=True)
    # tenx_rcn_lss = (tenx_ftrs_rcn - tenx_ftrs_gsub).square().mean()
    tenx_rcn_lss = nn.MSELoss()(tenx_ftrs_rcn, tenx_ftrs_gsub)

    tenx_r2 = get_r2_torch(tenx_ftrs_gsub, tenx_ftrs_rcn)

# %%
tenx_rcn_lss
# Out:
# tensor(0.2406)

# %%
fig, ax = plt.subplots()
# ax.plot(tenx_r2, label='10X')
ax.plot(tenx_r2, '-o', label='10X', markersize=1)
ax.set_ylim([-0.05,1.05])
ax.set_ylabel('Recon r2')
ax.set_xlabel(f'genes (n={len(tenx_r2)})')
ax.legend(bbox_to_anchor=(1,1))
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(np.sort(tenx_r2)[::-1], label='10X')
# ax.plot(np.sort(smrt_r2)[::-1], '-', label='SMART-seq',)
ax.set_ylim([-0.05,1.05])
ax.set_ylabel('Recon r2')
ax.set_xlabel(f'genes (n={len(tenx_r2)})')
ax.legend()
sns.despine(ax=ax)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(np.sort(tenx_r2)[::-1], label='10X')
# ax.plot(np.sort(smrt_r2)[::-1], '-', label='SMART-seq',)
# ax.set_ylim([-0.05,1.05])
ax.set_ylabel('Recon r2')
ax.set_xlabel(f'genes (n={len(tenx_r2)})')
ax.legend()
sns.despine(ax=ax)
plt.show()
