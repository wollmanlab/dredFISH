# %%
import nupack
import pandas as pd
import numpy as np

# import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set_context('talk')

from dredFISH.Utils.__init__plots import *

# %%
bitmap = [
     ('RS0109_cy5', 'hybe2', 'FarRed'),
     ('RS0175_cy5', 'hybe3', 'FarRed'),
     ('RS0237_cy5', 'hybe4', 'FarRed'),
     ('RS0307_cy5', 'hybe5', 'FarRed'),
     ('RS0332_cy5', 'hybe6', 'FarRed'),
     ('RS0384_atto565', 'hybe10', 'FarRed'),
     ('RS0406_atto565', 'hybe11', 'FarRed'),
     ('RS0451_atto565', 'hybe12', 'FarRed'),
     ('RS0468_atto565', 'hybe13', 'FarRed'),
     ('RS0548_atto565', 'hybe14', 'FarRed'),
     ('RS64.0_atto565', 'hybe15', 'FarRed'),
     ('RS156.0_alexa488', 'hybe19', 'FarRed'),
     ('RS278.0_alexa488', 'hybe20', 'FarRed'),
     ('RS313.0_alexa488', 'hybe21', 'FarRed'),
     ('RS643.0_alexa488', 'hybe22', 'FarRed'),
     ('RS740.0_alexa488', 'hybe23', 'FarRed'),
     ('RS810.0_alexa488', 'hybe24', 'FarRed'),
     ('RSN9927.0_cy5', 'hybe7', 'FarRed'),
     ('RSN2336.0_cy5', 'hybe8', 'FarRed'),
     ('RSN1807.0_cy5', 'hybe9', 'FarRed'),
     ('RSN4287.0_atto565', 'hybe16', 'FarRed'),
     ('RSN1252.0_atto565', 'hybe17', 'FarRed'),
     ('RSN9535.0_atto565', 'hybe18', 'FarRed'),
     ('RS0095_cy5', 'hybe1', 'FarRed'),
    ]
bitmap = pd.DataFrame(bitmap)
bitmap['bit'] = np.arange(24) 
bitmap['name'] = bitmap[0].apply(lambda x: x.split('_')[0])
bitmap['hybe'] = bitmap[1].apply(lambda x: int(x[4:]))
# bitmap = bitmap.set_index('name')
bitmap
# Out:
#                     0       1       2  bit       name  hybe
# 0          RS0109_cy5   hybe2  FarRed    0     RS0109     2
# 1          RS0175_cy5   hybe3  FarRed    1     RS0175     3
# 2          RS0237_cy5   hybe4  FarRed    2     RS0237     4
# 3          RS0307_cy5   hybe5  FarRed    3     RS0307     5
# 4          RS0332_cy5   hybe6  FarRed    4     RS0332     6
# 5      RS0384_atto565  hybe10  FarRed    5     RS0384    10
# 6      RS0406_atto565  hybe11  FarRed    6     RS0406    11
# 7      RS0451_atto565  hybe12  FarRed    7     RS0451    12
# 8      RS0468_atto565  hybe13  FarRed    8     RS0468    13
# 9      RS0548_atto565  hybe14  FarRed    9     RS0548    14
# 10     RS64.0_atto565  hybe15  FarRed   10     RS64.0    15
# 11   RS156.0_alexa488  hybe19  FarRed   11    RS156.0    19
# 12   RS278.0_alexa488  hybe20  FarRed   12    RS278.0    20
# 13   RS313.0_alexa488  hybe21  FarRed   13    RS313.0    21
# 14   RS643.0_alexa488  hybe22  FarRed   14    RS643.0    22
# 15   RS740.0_alexa488  hybe23  FarRed   15    RS740.0    23
# 16   RS810.0_alexa488  hybe24  FarRed   16    RS810.0    24
# 17      RSN9927.0_cy5   hybe7  FarRed   17  RSN9927.0     7
# 18      RSN2336.0_cy5   hybe8  FarRed   18  RSN2336.0     8
# 19      RSN1807.0_cy5   hybe9  FarRed   19  RSN1807.0     9
# 20  RSN4287.0_atto565  hybe16  FarRed   20  RSN4287.0    16
# 21  RSN1252.0_atto565  hybe17  FarRed   21  RSN1252.0    17
# 22  RSN9535.0_atto565  hybe18  FarRed   22  RSN9535.0    18
# 23         RS0095_cy5   hybe1  FarRed   23     RS0095     1

# %%
f = "/greendata/GeneralStorage/fangming/projects/dredfish/res_seq/readout_29bits_Nov17_2022.csv"
df = pd.read_csv(f, index_col=0)[:24]
df
# Out:
#          name           seq_readout            seq_encode
# 0      RS0095  ACTCCACTACTACTCACTCT  AGAGTGAGTAGTAGTGGAGT
# 1      RS0109  ACCCTCTAACTTCCATCACA  TGTGATGGAAGTTAGAGGGT
# 2      RS0175  ACCACAACCCATTCCTTTCA  TGAAAGGAATGGGTTGTGGT
# 3      RS0237  TTTCTACCACTAATCAACCC  GGGTTGATTAGTGGTAGAAA
# 4      RS0307  TATCCTTCAATCCCTCCACA  TGTGGAGGGATTGAAGGATA
# 5      RS0332  ACATTACACCTCATTCTCCC  GGGAGAATGAGGTGTAATGT
# 6      RS0384  TTCTCCCTCTATCAACTCTA  TAGAGTTGATAGAGGGAGAA
# 7      RS0406  ACCCTTACTACTACATCATC  GATGATGTAGTAGTAAGGGT
# 8      RS0451  TCCTAACAACCAACTACTCC  GGAGTAGTTGGTTGTTAGGA
# 9      RS0468  TCTATCATTACCCTCCTCCT  AGGAGGAGGGTAATGATAGA
# 10     RS0548  TATTCACCTTACAAACCCTC  GAGGGTTTGTAAGGTGAATA
# 11    RS156.0  CCACCTTCCTACATAATACC  GGTATTATGTAGGAAGGTGG
# 12    RS278.0  ACACTCTACAACCACTTCTC  GAGAAGTGGTTGTAGAGTGT
# 13    RS313.0  AACACCACAACCTACTAACC  GGTTAGTAGGTTGTGGTGTT
# 14     RS64.0  TCACTCAATCACCTCACTTC  GAAGTGAGGTGATTGAGTGA
# 15    RS643.0  CACCACCAATCACCTTATAC  GTATAAGGTGATTGGTGGTG
# 16    RS740.0  ACTACACATCAACCTACTCC  GGAGTAGGTTGATGTGTAGT
# 17    RS810.0  ACCTACCTTAACACACACTC  GAGTGTGTGTTAAGGTAGGT
# 18  RSN1252.0  CCAATACCTAATCCTCTCTC  GAGAGAGGATTAGGTATTGG
# 19  RSN1807.0  ACCATCCTTAATCAACCACC  GGTGGTTGATTAAGGATGGT
# 20  RSN2336.0  CACATTCTCACCACTCACAT  ATGTGAGTGGTGAGAATGTG
# 21  RSN4287.0  CCTCACAAATTCTAACCTCC  GGAGGTTAGAATTTGTGAGG
# 22  RSN9535.0  CCTCCTAACATAACACCTAC  GTAGGTGTTATGTTAGGAGG
# 23  RSN9927.0  CAACCACTAACCTCTAACCA  TGGTTAGAGGTTAGTGGTTG

# %%
output = "/greendata/GeneralStorage/fangming/projects/dredfish/res_seq/readout_24bits_Jan2023.csv"
df = pd.merge(bitmap, df, on='name').sort_values('hybe')[['hybe', 'bit', 'name', 'seq_readout', 'seq_encode']]
df
# Out:
#     hybe  bit       name           seq_readout            seq_encode
# 23     1   23     RS0095  ACTCCACTACTACTCACTCT  AGAGTGAGTAGTAGTGGAGT
# 0      2    0     RS0109  ACCCTCTAACTTCCATCACA  TGTGATGGAAGTTAGAGGGT
# 1      3    1     RS0175  ACCACAACCCATTCCTTTCA  TGAAAGGAATGGGTTGTGGT
# 2      4    2     RS0237  TTTCTACCACTAATCAACCC  GGGTTGATTAGTGGTAGAAA
# 3      5    3     RS0307  TATCCTTCAATCCCTCCACA  TGTGGAGGGATTGAAGGATA
# 4      6    4     RS0332  ACATTACACCTCATTCTCCC  GGGAGAATGAGGTGTAATGT
# 17     7   17  RSN9927.0  CAACCACTAACCTCTAACCA  TGGTTAGAGGTTAGTGGTTG
# 18     8   18  RSN2336.0  CACATTCTCACCACTCACAT  ATGTGAGTGGTGAGAATGTG
# 19     9   19  RSN1807.0  ACCATCCTTAATCAACCACC  GGTGGTTGATTAAGGATGGT
# 5     10    5     RS0384  TTCTCCCTCTATCAACTCTA  TAGAGTTGATAGAGGGAGAA
# 6     11    6     RS0406  ACCCTTACTACTACATCATC  GATGATGTAGTAGTAAGGGT
# 7     12    7     RS0451  TCCTAACAACCAACTACTCC  GGAGTAGTTGGTTGTTAGGA
# 8     13    8     RS0468  TCTATCATTACCCTCCTCCT  AGGAGGAGGGTAATGATAGA
# 9     14    9     RS0548  TATTCACCTTACAAACCCTC  GAGGGTTTGTAAGGTGAATA
# 10    15   10     RS64.0  TCACTCAATCACCTCACTTC  GAAGTGAGGTGATTGAGTGA
# 20    16   20  RSN4287.0  CCTCACAAATTCTAACCTCC  GGAGGTTAGAATTTGTGAGG
# 21    17   21  RSN1252.0  CCAATACCTAATCCTCTCTC  GAGAGAGGATTAGGTATTGG
# 22    18   22  RSN9535.0  CCTCCTAACATAACACCTAC  GTAGGTGTTATGTTAGGAGG
# 11    19   11    RS156.0  CCACCTTCCTACATAATACC  GGTATTATGTAGGAAGGTGG
# 12    20   12    RS278.0  ACACTCTACAACCACTTCTC  GAGAAGTGGTTGTAGAGTGT
# 13    21   13    RS313.0  AACACCACAACCTACTAACC  GGTTAGTAGGTTGTGGTGTT
# 14    22   14    RS643.0  CACCACCAATCACCTTATAC  GTATAAGGTGATTGGTGGTG
# 15    23   15    RS740.0  ACTACACATCAACCTACTCC  GGAGTAGGTTGATGTGTAGT
# 16    24   16    RS810.0  ACCTACCTTAACACACACTC  GAGTGTGTGTTAAGGTAGGT

# %%
df.to_csv(output, index=False)
