# %%
import nupack
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
f = "/greendata/GeneralStorage/fangming/projects/dredfish/res_seq/readout_29bits_Nov17_2022.csv"
df = pd.read_csv(f, index_col=0)
seqs = df['seq_readout'][:24]
seqs_enc = df['seq_encode'][:24]
seqs
# Out:
# 0     ACTCCACTACTACTCACTCT
# 1     ACCCTCTAACTTCCATCACA
# 2     ACCACAACCCATTCCTTTCA
# 3     TTTCTACCACTAATCAACCC
# 4     TATCCTTCAATCCCTCCACA
# 5     ACATTACACCTCATTCTCCC
# 6     TTCTCCCTCTATCAACTCTA
# 7     ACCCTTACTACTACATCATC
# 8     TCCTAACAACCAACTACTCC
# 9     TCTATCATTACCCTCCTCCT
# 10    TATTCACCTTACAAACCCTC
# 11    CCACCTTCCTACATAATACC
# 12    ACACTCTACAACCACTTCTC
# 13    AACACCACAACCTACTAACC
# 14    TCACTCAATCACCTCACTTC
# 15    CACCACCAATCACCTTATAC
# 16    ACTACACATCAACCTACTCC
# 17    ACCTACCTTAACACACACTC
# 18    CCAATACCTAATCCTCTCTC
# 19    ACCATCCTTAATCAACCACC
# 20    CACATTCTCACCACTCACAT
# 21    CCTCACAAATTCTAACCTCC
# 22    CCTCCTAACATAACACCTAC
# 23    CAACCACTAACCTCTAACCA
# Name: seq_readout, dtype: object

# %%
# %%time
# specify strands
strands =  [nupack.Strand(seq, name=f"e{i}") for i, seq in enumerate(seqs_enc)] #[:20]
strands += [nupack.Strand(seq, name=f"r{i}") for i, seq in enumerate(seqs)][0:1]

# specify tubes
t1 = nupack.Tube(strands={strand: 1e-8 for strand in strands}, 
                 complexes=nupack.SetSpec(max_size=2), 
                 name='t1')

# analyze tubes
model1 = nupack.Model(material='dna', 
                      celsius=37,
                      sodium=1,
                     )
tube_results = nupack.tube_analysis(tubes=[t1], model=model1)
# tube_results
# Out:
# CPU times: user 853 ms, sys: 153 ms, total: 1.01 s
# Wall time: 796 ms

# %%
tube_results
# Out:
# Result(tubes={<Tube t1>: <nupack.named.TubeResult object at 0x7fca709f1280>}, complexes={<Complex (e17+e11)>: nupack.analysis.ComplexResult({model: Model('stacking', 'dna04.json', T=310.15 K), pfunc: 11093.28905, free_energy: -5.740470631863512}), <Complex (e10+e23)>: nupack.analysis.ComplexResult({model: Model('stacking', 'dna04.json', T=310.15 K), pfunc: 16068.93893, free_energy: -5.968846948459839}), <Complex (e5+e4)>: nupack.analysis.ComplexResult({model: Model('stacking', 'dna04.json', T=310.15 K), pfunc: 43397.63088, free_energy: -6.581171932575595}), <Complex (e9+e19)>: nupack.analysis.ComplexResult({model: Model('stacking', 'dna04.json', T=310.15 K), pfunc: 32716.06654, free_energy: -6.407037546452305}), <Complex (e20+e3)>: nupack.analysis.ComplexResult({model: Model('stacking', 'dna04.json', T=310.15 K), pfunc: 23202.21750, free_energy: -6.195258367489951}), <Complex (e12+e10)>: nupack.analysis.ComplexResult({model: Model('stacking', 'dna04.json', T=310.15 K), pfunc: 16379.0
# ...

# %%
conc = pd.Series({key.name.strip("()"): item for key, item in 
        tube_results['t1'].complex_concentrations.items()
       })
conc
# Out:
# e17+e11    7.907349e-15
# e10+e23    9.106926e-15
# e5+e4      1.689278e-14
# e9+e19     1.657821e-14
# e20+e3     1.388407e-14
#                ...
# e15+e6     9.136107e-15
# r0+e2      2.132524e-16
# e10+e6     1.083410e-14
# e10+e3     1.989357e-14
# e0+e4      2.744644e-19
# Length: 350, dtype: float64

# %%
plt.plot(np.sort(conc))
plt.yscale('log')
plt.xlabel('Complex')
plt.ylabel('Concentration (M)')
# Out:
# Text(0, 0.5, 'Concentration (M)')

# %%
conc.sort_values(ascending=False) # iloc['(r1)']
# Out:
# e12       9.999858e-09
# e23       9.999844e-09
# e2        9.999842e-09
# e13       9.999833e-09
# e17       9.999829e-09
#               ...
# e0+e15    2.599583e-19
# e0+e19    2.595200e-19
# e0+e2     2.237803e-19
# e0+e0     4.414666e-23
# r0+r0     5.816895e-24
# Length: 350, dtype: float64

# %%
conc.filter(regex='r0\+enc')
# Out:
# Series([], dtype: float64)

# %%
# e2e
e2e = conc.filter(regex=r'^e[0-9]{1,2}\+e[0-9]{1,2}$') #.sum()
e2e
# Out:
# e17+e11    7.907349e-15
# e10+e23    9.106926e-15
# e5+e4      1.689278e-14
# e9+e19     1.657821e-14
# e20+e3     1.388407e-14
#                ...
# e0+e13     5.130634e-19
# e15+e6     9.136107e-15
# e10+e6     1.083410e-14
# e10+e3     1.989357e-14
# e0+e4      2.744644e-19
# Length: 300, dtype: float64

# %%
conc.filter(regex=r'r0')#.sum()
# Out:
# r0+e22    1.856224e-16
# r0+e6     9.523033e-15
# r0+e12    3.825158e-15
# r0+e1     2.521450e-16
# r0+e13    1.246549e-14
# r0+e4     4.135785e-15
# r0+e19    9.684041e-17
# r0+e0     9.999380e-09
# r0+e18    2.123167e-16
# r0+e16    1.572761e-15
# r0+e10    5.304065e-17
# r0+e11    1.396488e-16
# r0+e9     3.691778e-16
# r0+e20    8.676710e-15
# r0+e8     2.016234e-14
# r0+e17    1.203246e-15
# r0+e14    7.648152e-15
# r0+e7     2.825832e-14
# r0+e5     4.022215e-16
# r0+e15    1.423326e-16
# r0+e23    1.896880e-15
# r0+e3     1.496987e-15
# r0+r0     5.816895e-24
# r0        5.167689e-13
# r0+e21    2.985114e-16
# r0+e2     2.132524e-16
# dtype: float64

# %%
conc.filter(regex=r'\+')#.sum()
# Out:
# e17+e11    7.907349e-15
# e10+e23    9.106926e-15
# e5+e4      1.689278e-14
# e9+e19     1.657821e-14
# e20+e3     1.388407e-14
#                ...
# e15+e6     9.136107e-15
# r0+e2      2.132524e-16
# e10+e6     1.083410e-14
# e10+e3     1.989357e-14
# e0+e4      2.744644e-19
# Length: 325, dtype: float64

# %%
conc_mo = conc.filter(regex=r'^(?!.*\+).*$')
conc_di = conc.filter(regex=r'\+')
conc_di.shape, conc_mo.shape, conc.shape
# Out:
# ((325,), (25,), (350,))

# %%
conc_di.filter(regex=r'r') #.shape
# Out:
# r0+e22    1.856224e-16
# r0+e6     9.523033e-15
# r0+e12    3.825158e-15
# r0+e1     2.521450e-16
# r0+e13    1.246549e-14
# r0+e4     4.135785e-15
# r0+e19    9.684041e-17
# r0+e0     9.999380e-09
# r0+e18    2.123167e-16
# r0+e16    1.572761e-15
# r0+e10    5.304065e-17
# r0+e11    1.396488e-16
# r0+e9     3.691778e-16
# r0+e20    8.676710e-15
# r0+e8     2.016234e-14
# r0+e17    1.203246e-15
# r0+e14    7.648152e-15
# r0+e7     2.825832e-14
# r0+e5     4.022215e-16
# r0+e15    1.423326e-16
# r0+e23    1.896880e-15
# r0+e3     1.496987e-15
# r0+r0     5.816895e-24
# r0+e21    2.985114e-16
# r0+e2     2.132524e-16
# dtype: float64

# %%
def fraction_of_signal(conc, signal='r0+e0'):
    """
    """
    conc_sub = conc.filter(regex=r'\+').filter(regex=r'r')
    frac = conc_sub.loc[signal]/conc_sub.sum()
    return frac

# %%
frac = fraction_of_signal(conc, signal='r0+e0')

# %%
frac
# Out:
# 0.9999896764687982
