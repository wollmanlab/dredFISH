# %%
import os
base_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
processing_key = 'Processing_2024May28'
for dataset in sorted(os.listdir(base_path)):
    if not '_' in dataset:
        continue
    if not len([i for i in os.listdir(os.path.join(base_path,dataset)) if 'ybe7' in i]) > 0:
        continue
    if os.path.exists(os.path.join(base_path,dataset,processing_key)):
        continue
    # if 'PTZ' in dataset:
    #     continue
    if 'PTZ' in dataset:
        continue
    print(f"conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py {os.path.join(base_path,dataset)} > {os.path.join(base_path,dataset,'processing_nohup.out')} &")
    print(' ')
# Out:
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTF06_6.2.A_7.2.B_8.2.C_9.1.D_10.2.E_11.1.F_2024Jun17 > /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTF06_6.2.A_7.2.B_8.2.C_9.1.D_10.2.E_11.1.F_2024Jun17/processing_nohup.out &

# %%
import os
from dredFISH.Utils import fileu
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

processing_key = 'Processing_2024May28'
project_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
datasets = [i for i in os.listdir(project_path) if '_' in i]
status = {}
for dataset in sorted(datasets):
    processing_path = os.path.join(project_path,dataset,processing_key)
    if not os.path.exists(processing_path):
        continue
    status[dataset] = {}
    sections = [i for i in os.listdir(processing_path) if '-' in i]
    for section in sections:
        data_path = fileu.generate_filename(path=os.path.join(processing_path,section),hybe='',channel='',file_type='anndata')
        if os.path.exists(data_path):
            status[dataset][section] = True
        else:
            status[dataset][section] = False
total = 0
not_completed_datasets = []
for dataset,dataset_status in status.items():
    completed = np.sum([value for section,value in dataset_status.items()])
    total+=completed
    not_completed = np.sum([value==False for section,value in dataset_status.items()])
    if not_completed > 0:
        not_completed_datasets.append(dataset)
        print(f"{completed} Completed Sections for \033[91m{dataset}\033[0m {not_completed}")
    else:
        print(f"{completed} Completed Sections for \033[92m{dataset}\033[0m ")
print(f"{total} Completed Sections for All")
# Out:
# 24 Completed Sections for ASDM02_4.2.D_4.2.E_6.2.F_1.2.A_2.2.B_3.2.C_2024May20
# 23 Completed Sections for ASDM02_6.3.A_5.3.B_4.3.C_1.3.D_2.3.E_3.3.F_2024Jun10
# 24 Completed Sections for ASDM02_7.3.A_8.3.B_9.3.C_12.3.D_11.3.E_10.3.F_2024Jun10
# 24 Completed Sections for ASDM02_9.2.A_8.2.B_7.2.C_12.2.D_11.2.E_10.2.F_2024May20
# 24 Completed Sections for MMSF01_6.3.A_5.3.B_4.3.C_3.3.F_2.3.E_1.3.D_2024Apr15
# 24 Completed Sections for MMSM01_1.1.A_2.1.B_3.1.C_4.1.F_5.1.E_6.1.D_2024Apr15
# 24 Completed Sections for WTF01_1.2.A_2.2.B_3.2.C_4.2.D_5.2.E_6.2.F_2024Apr08
# 24 Completed Sections for WTF04_4.1.D_5.1.E_6.1.F_1.1.A_2.1.B_3.1.C_2024Jun3
# 20 Completed Sections for WTF04_9.1.A_8.1.B_7.1.C_11.1.E_10.1.F_2024Jun3
# 0 Completed Sections for WTF05_6.3.A_7.3.B_8.3.C_9.3.D_10.3.E_11.3.F_2024Jun17 1
# 24 Completed Sections for WTM01_3.2.A_2.2.B_1.2.C_6.2.D_5.2.E_4.2.F_2024Apr08
# 15 Completed Sections for WTM02_2.2.A_1.1.B_2.1.D_3.2.E_2024Apr01 1
# 16 Completed Sections for WTM02_3.1.A_2.3.B_3.3.D_1.2.E_2024Apr01
# 24 Completed Sections for WTM04_10.2.A_11.2.B_12.2.C_7.2.D_8.2.E_9.2.F_2024May13
# 24 Completed Sections for WTM04_3.2.D_2.2.E_1.2.F_6.2.A_5.2.B_4.2.C_2024May13
# 10 Completed Sections for WTM04_4.3.D_5.3.E_6.3.F_1.3.A_2.3.B_3.3.C_2024May28 1
# 7 Completed Sections for WTM04_9.3.A_8.3.B_7.3.C_12.3.D_11.3.E_10.3.F_2024May28 1
# 0 Completed Sections for WTM06_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun17 1
# 0 Completed Sections for WTM07_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun24 1
# 331 Completed Sections for All

# %%
conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM04_4.3.D_5.3.E_6.3.F_1.3.A_2.3.B_3.3.C_2024May28 > /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM04_4.3.D_5.3.E_6.3.F_1.3.A_2.3.B_3.3.C_2024May28/processing_nohup.out &

conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTF05_6.3.A_7.3.B_8.3.C_9.3.D_10.3.E_11.3.F_2024Jun17 > /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTF05_6.3.A_7.3.B_8.3.C_9.3.D_10.3.E_11.3.F_2024Jun17/processing_nohup.out &
 
conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM04_9.3.A_8.3.B_7.3.C_12.3.D_11.3.E_10.3.F_2024May28 > /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM04_9.3.A_8.3.B_7.3.C_12.3.D_11.3.E_10.3.F_2024May28/processing_nohup.out &
 
conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM06_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun17 > /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM06_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun17/processing_nohup.out &
 
conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM07_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun24 > /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM07_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun24/processing_nohup.out &

# %%
conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM02_2.2.A_1.1.B_2.1.D_3.2.E_2024Apr01 -s WellE-Section4 > /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM02_2.2.A_1.1.B_2.1.D_3.2.E_2024Apr01/processing_nohup.out &

# %%
import os
base_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
proccessing_name = 'Processing_2024May28'
for dataset in not_completed_datasets:#sorted(os.listdir(base_path)):
    # if 'ASD' in dataset.split('_')[0]:
    #     continue
    if not os.path.exists(os.path.join(base_path,dataset,proccessing_name)):
        continue
    for processing in os.listdir(os.path.join(base_path,dataset)):
        if 'processing' in processing.split('_')[0]:
            print(f"{dataset} \033[91m{processing}\033[0m")
            print(os.path.join(base_path,dataset,processing))
            print(' ')
            ! tail -10 {os.path.join(base_path,dataset,processing)}
            print(' ')
# Out:
# WTF05_6.3.A_7.3.B_8.3.C_9.3.D_10.3.E_11.3.F_2024Jun17 processing_nohup.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTF05_6.3.A_7.3.B_8.3.C_9.3.D_10.3.E_11.3.F_2024Jun17/processing_nohup.out
#
# 2024 July 02 07:11:01  Hybe23_293 Computing FF and Constant Now
# 2024 July 02 07:14:53  Hybe23_295 Computing FF and Constant Now
# 2024 July 02 07:19:27  Hybe23_292 Computing FF and Constant Now
# 2024 July 02 07:23:22 Loading FF and Constant For entire Round for Strip23 DeepBlue
# 2024 July 02 07:23:22  Strip23_287 Computing FF and Constant Now
# 2024 July 02 07:28:22  Strip23_285 Computing FF and Constant Now
# 2024 July 02 07:34:06  Strip23_288 Computing FF and Constant Now
# 2024 July 02 07:38:32  Strip23_286 Computing FF and Constant Now
# 2024 July 02 07:42:01  Strip23_284 Computing FF and Constant Now
# 2024 July 02 07:47:04  Strip23_289 Computing FF and Constant Now
#
# WTM02_2.2.A_1.1.B_2.1.D_3.2.E_2024Apr01 processing_nohup.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM02_2.2.A_1.1.B_2.1.D_3.2.E_2024Apr01/processing_nohup.out
#
#     self.run()
#   File "/home/zach/PythonRepos/dredFISH/dredFISH/Processing/Section.py", line 99, in run
#     self.main()
#   File "/home/zach/PythonRepos/dredFISH/dredFISH/Processing/Section.py", line 127, in main
#     self.stitch()
#   File "/home/zach/PythonRepos/dredFISH/dredFISH/Processing/Section.py", line 1020, in stitch
#     self.reference_stitched = self.stitcher(self.parameters['nucstain_acq'],self.parameters['total_channel'])
#   File "/home/zach/PythonRepos/dredFISH/dredFISH/Processing/Section.py", line 751, in stitcher
#     data['bkg_nuc'] = nuc_bkg_fnames[posname][0]
# KeyError: 'WellE-Section4-Pos676_17_36'
#
# WTM04_4.3.D_5.3.E_6.3.F_1.3.A_2.3.B_3.3.C_2024May28 processing_nohup.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM04_4.3.D_5.3.E_6.3.F_1.3.A_2.3.B_3.3.C_2024May28/processing_nohup.out
#
# 2024 July 02 08:27:47 Loading FF and Constant For entire Round for Strip5 DeepBlue
# 2024 July 02 08:27:50 Processing Hybe5_126_FarRed
# 2024 July 02 08:32:44 Registering Hybe5_126_FarRed
# 2024 July 02 08:32:45 Stitching Hybe5_126_FarRed
# 2024 July 02 08:33:53 Detected Hybe17_246 as hybe17's Acquisition
# 2024 July 02 08:33:53 Detected Strip17_240 as Hybe17_246's Background
# 2024 July 02 08:33:55 Loading FF and Constant For entire Round for Hybe17 FarRed
# 2024 July 02 08:33:56 Loading FF and Constant For entire Round for Strip17 FarRed
# 2024 July 02 08:33:57 Loading FF and Constant For entire Round for Hybe17 DeepBlue
# 2024 July 02 08:33:59 Loading FF and Constant For entire Round for Strip17 DeepBlue
#
# WTM04_9.3.A_8.3.B_7.3.C_12.3.D_11.3.E_10.3.F_2024May28 processing_nohup.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM04_9.3.A_8.3.B_7.3.C_12.3.D_11.3.E_10.3.F_2024May28/processing_nohup.out
#
# 2024 July 02 09:08:02 WellB-Section4-Pos929_27_19 failed first round of stitching during registration
# 2024 July 02 09:08:02 WellB-Section4-Pos894_26_19 failed first round of stitching during registration
# 2024 July 02 09:08:02 WellB-Section4-Pos859_25_19 failed first round of stitching during registration
# 2024 July 02 09:08:02 Stitching Hybe20_105_FarRed
# 2024 July 02 09:08:46 Detected Hybe4_201 as hybe4's Acquisition
# 2024 July 02 09:08:46 Detected Strip4_195 as Hybe4_201's Background
# 2024 July 02 09:08:51 Loading FF and Constant For entire Round for Hybe4 FarRed
# 2024 July 02 09:08:52 Loading FF and Constant For entire Round for Strip4 FarRed
# 2024 July 02 09:08:52 Loading FF and Constant For entire Round for Hybe4 DeepBlue
# 2024 July 02 09:08:52 Loading FF and Constant For entire Round for Strip4 DeepBlue
#
# WTM06_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun17 processing_nohup.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM06_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun17/processing_nohup.out
#
# 2024 July 02 08:07:27  Hybe1_153 Computing FF and Constant Now
# 2024 July 02 08:11:34  Hybe1_152 Computing FF and Constant Now
# 2024 July 02 08:17:24  Hybe1_151 Computing FF and Constant Now
# 2024 July 02 08:21:55 Loading FF and Constant For entire Round for Strip1 DeepBlue
# 2024 July 02 08:21:55  Strip1_148 Computing FF and Constant Now
# 2024 July 02 08:26:12  Strip1_147 Computing FF and Constant Now
# 2024 July 02 08:30:17  Strip1_146 Computing FF and Constant Now
# 2024 July 02 08:35:21  Strip1_150 Computing FF and Constant Now
# 2024 July 02 08:39:55  Strip1_149 Computing FF and Constant Now
# 2024 July 02 08:44:13  Strip1_145 Computing FF and Constant Now
#
# WTM07_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun24 processing_nohup.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/WTM07_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun24/processing_nohup.out
#
# 2024 July 02 06:14:00  Hybe17_244 Computing FF and Constant Now
# 2024 July 02 06:18:48  Hybe17_241 Computing FF and Constant Now
# 2024 July 02 06:24:28  Hybe17_245 Computing FF and Constant Now
# 2024 July 02 06:29:07 Loading FF and Constant For entire Round for Strip17 DeepBlue
# 2024 July 02 06:29:07  Strip17_238 Computing FF and Constant Now
# 2024 July 02 06:34:15  Strip17_235 Computing FF and Constant Now
# 2024 July 02 06:39:57  Strip17_239 Computing FF and Constant Now
# 2024 July 02 06:44:20  Strip17_236 Computing FF and Constant Now
# 2024 July 02 06:51:53  Strip17_237 Computing FF and Constant Now
# 2024 July 02 06:56:31  Strip17_240 Computing FF and Constant Now

# %%
import os
base_path = '/orangedata/Images2024/Zach/MouseBrainAtlas/'
proccessing_name = 'Processing_2024May01'
for dataset in sorted(os.listdir(base_path)):
    print(f"conda activate dredfish_3.9 ; python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Registration/execute.py {os.path.join(base_path,dataset)} -f {proccessing_name} > {os.path.join(base_path,dataset,'registration_nohup.out')} &")
    print(' ')

# %%
for animal in ['WTM01','WTF01','MMSF01','MMSM01']:
    print(f"conda activate dredfish_3.9 ; python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py {animal}")
    print(' ')
# Out:
# conda activate dredfish_3.9 ; python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py WTM01
#
# conda activate dredfish_3.9 ; python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py WTF01
#
# conda activate dredfish_3.9 ; python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py MMSF01
#
# conda activate dredfish_3.9 ; python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py MMSM01

# %%
import os
import datetime

storage_directories = [i for i in os.listdir('/') if 'data' in i[-4:]]
destination = 'scratchdata1'
if not os.path.exists(os.path.join('/',destination)):
    print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.mkdir({os.path.join('/',destination)}, mode=0o775)")
    os.mkdir(os.path.join('/',destination), mode=0o775)
for storage in storage_directories:
    for year in os.listdir(os.path.join('/',storage)):
        if 'External' in year:
            if not os.path.exists(os.path.join('/',destination,year)):
                print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.symlink({os.path.join('/',storage,year)}, {os.path.join('/',destination,year)})")
                os.symlink(os.path.join('/',storage,year), os.path.join('/',destination,year))
                continue
        if not 'Images' in year:
            continue
        if not os.path.exists(os.path.join('/',destination,year)):
            print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.mkdir({os.path.join('/',destination,year)}, mode=0o775)")
            os.mkdir(os.path.join('/',destination,year), mode=0o775)
        for user in os.listdir(os.path.join('/',storage,year)):
            if not os.path.isdir(os.path.join('/',storage,year,user)):
                continue
            if not os.path.exists(os.path.join('/',destination,year,user)):
                print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.mkdir({os.path.join('/',destination,year,user)}, mode=0o775)")
                os.mkdir(os.path.join('/',destination,year,user), mode=0o775)
            try:
                for project in os.listdir(os.path.join('/',storage,year,user)):
                    if not os.path.isdir(os.path.join('/',storage,year,user,project)):
                        continue
                    if not os.path.exists(os.path.join('/',destination,year,user,project)):
                        print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.mkdir({os.path.join('/',destination,year,user,project)}, mode=0o775)")
                        os.mkdir(os.path.join('/',destination,year,user,project), mode=0o775)
                    try:
                        for dataset in os.listdir(os.path.join('/',storage,year,user,project)):
                            if not os.path.isdir(os.path.join('/',storage,year,user,project,dataset)):
                                continue
                            if not os.path.exists(os.path.join('/',destination,year,user,project,dataset)):
                                print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.symlink({os.path.join('/',storage,year,user,project,dataset)}, {os.path.join('/',destination,year,user,project,dataset)})")
                                os.symlink(os.path.join('/',storage,year,user,project,dataset), os.path.join('/',destination,year,user,project,dataset))
                    except:
                        print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')}  Failed {os.path.join('/',storage,year,user,project,dataset)}")
                        pass
            except:
                print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')}  Failed {os.path.join('/',storage,year,user,project)}")
                pass
# Out:
#  2024Jul02 09:07:35  Failed /greendata/Images2019/Zach/TNF_3T3/z-stacks.zip
#  2024Jul02 09:07:57  Failed /greendata/Images2021/Gaby/NN_2021Jul01/uncleared_1
#  2024Jul02 09:08:04 os.mkdir(/scratchdata1/Images2024/Aihui/superprobe_July, mode=0o775)
#  2024Jul02 09:08:04 os.symlink(/purpledata/Images2024/Aihui/superprobe_July/DNA_2024Jul01, /scratchdata1/Images2024/Aihui/superprobe_July/DNA_2024Jul01)
#  2024Jul02 09:08:12  Failed /bluedata/Images2023/test_folder_permission/Elegans
#  2024Jul02 09:08:12  Failed /bluedata/Images2023/Zach/thick_dredFISH/smFISH_older.D_newer.E_2023Feb24

# %%
base_path = '/scratchdata1/Images2024/Zach/'
def get_directory_size(path):
    """Recursively calculates the size of a directory and its contents in bytes."""
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(path):
        for filename in filenames:
            filepath = os.path.join(dirpath, filename)
            total_size += os.path.getsize(filepath)
    return total_size
import shutil
storage_directories = [i for i in os.listdir('/') if 'data' in i[-4:]]
for storage in storage_directories:
    total_savings = 0
    # print(' ')
    # print(storage)
    # print(' ')
    for year in os.listdir(os.path.join('/',storage)):
        if not 'Images' in year:
            continue
        for user in ['Zach','Gaby','gaby','Thomas','Haley','Sofia']:
            base_path = os.path.join('/',storage,year,user)
            if not os.path.exists(base_path):
                continue
            """ check if i have permission"""
            if not os.access(os.path.join(base_path), os.W_OK):
                continue
            for projects in os.listdir(base_path):
                if not os.path.isdir(os.path.join(base_path,projects)):
                    continue
                """ check if i have permission"""
                if not os.access(os.path.join(base_path,projects), os.W_OK):
                    continue
                for dataset in os.listdir(os.path.join(base_path,projects)):
                    if not os.path.isdir(os.path.join(base_path,projects,dataset)):
                        continue
                    """ check if i have permission"""
                    if not os.access(os.path.join(base_path,projects,dataset), os.W_OK):
                        continue
                    for acq in os.listdir(os.path.join(base_path,projects,dataset)):
                        if not 'acq' in acq:
                            continue
                        if not os.path.isdir(os.path.join(base_path,projects,dataset,acq)):
                            continue
                        """ check if i have permission"""
                        if not os.access(os.path.join(base_path,projects,dataset,acq), os.W_OK):
                            continue
                        for pos in os.listdir(os.path.join(base_path,projects,dataset,acq)):
                            # if 'Metadata' in pos:
                                # os.rename(os.path.join(base_path,projects,dataset,acq,pos), os.path.join(base_path,projects,dataset,'Ignore_'+pos))
                            if not os.path.isdir(os.path.join(base_path,projects,dataset,acq,pos)):
                                continue
                            """ check if i have permission"""
                            if not os.access(os.path.join(base_path,projects,dataset,acq,pos), os.W_OK):
                                continue
                            """ get size of directory """
                            size = get_directory_size(os.path.join(base_path,projects,dataset,acq,pos))
                            total_savings += size
                            # print(f"{total_savings/(1024**3):.2f}",end="\r" )
    print(f"{storage} {total_savings/(1024**3):.2f}")
