# %%
""" Maintain Scratchdata1 """

import os
import datetime

storage_directories = [i for i in os.listdir('/') if 'data' in i[-4:]]
destination = 'scratchdata1'
if not os.path.exists(os.path.join('/',destination)):
    print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.mkdir({os.path.join('/',destination)}, mode=0o775)")
    os.mkdir(os.path.join('/',destination), mode=0o775)
if not os.path.exists(os.path.join('/',destination,'home')):
    print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.symlink({os.path.join('/','home')}, {os.path.join('/',destination,'home')})")
    os.symlink(os.path.join('/','home'), os.path.join('/',destination,'home'))
for storage in storage_directories:
    for year in os.listdir(os.path.join('/',storage)):
        if 'External' in year:
            if not os.path.exists(os.path.join('/',destination,year)):
                print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.symlink({os.path.join('/',storage,year)}, {os.path.join('/',destination,year)})")
                os.symlink(os.path.join('/',storage,year), os.path.join('/',destination,year))
                continue
        if 'General' in year:
            if not os.path.exists(os.path.join('/',destination,year)):
                print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.symlink({os.path.join('/',storage,year)}, {os.path.join('/',destination,year)})")
                os.symlink(os.path.join('/',storage,year), os.path.join('/',destination,year))
                continue
        if not 'Images' in year:
            continue
        if not os.path.exists(os.path.join('/',destination,year)):
            print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.mkdir({os.path.join('/',destination,year)}, mode=0o775)")
            os.mkdir(os.path.join('/',destination,year), mode=0o775)
        for user in os.listdir(os.path.join('/',storage,year)):
            if not os.path.isdir(os.path.join('/',storage,year,user)):
                continue
            if not os.path.exists(os.path.join('/',destination,year,user)):
                print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.mkdir({os.path.join('/',destination,year,user)}, mode=0o775)")
                os.mkdir(os.path.join('/',destination,year,user), mode=0o775)
            try:
                for project in os.listdir(os.path.join('/',storage,year,user)):
                    if not os.path.isdir(os.path.join('/',storage,year,user,project)):
                        continue
                    if not os.path.exists(os.path.join('/',destination,year,user,project)):
                        print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.mkdir({os.path.join('/',destination,year,user,project)}, mode=0o775)")
                        os.mkdir(os.path.join('/',destination,year,user,project), mode=0o775)
                    try:
                        for dataset in os.listdir(os.path.join('/',storage,year,user,project)):
                            if not os.path.isdir(os.path.join('/',storage,year,user,project,dataset)):
                                continue
                            if not os.path.exists(os.path.join('/',destination,year,user,project,dataset)):
                                print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.symlink({os.path.join('/',storage,year,user,project,dataset)}, {os.path.join('/',destination,year,user,project,dataset)})")
                                os.symlink(os.path.join('/',storage,year,user,project,dataset), os.path.join('/',destination,year,user,project,dataset))
                    except:
                        print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')}  Failed {os.path.join('/',storage,year,user,project,dataset)}")
                        pass
            except:
                print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')}  Failed {os.path.join('/',storage,year,user,project)}")
                pass
# Out:
#  2024Sep04 22:08:06  Failed /bluedata/Images2023/test_folder_permission/Elegans
#  2024Sep04 22:08:06  Failed /bluedata/Images2023/Zach/thick_dredFISH/smFISH_older.D_newer.E_2023Feb24
#  2024Sep04 22:08:09  Failed /greendata/Images2019/Zach/TNF_3T3/z-stacks.zip
#  2024Sep04 22:08:15  Failed /greendata/Images2021/Gaby/NN_2021Jul01/uncleared_1
#  2024Sep04 22:08:17 os.mkdir(/scratchdata1/Images2024/Aihui/Superprobe, mode=0o775)
#  2024Sep04 22:08:17 os.symlink(/purpledata/Images2024/Aihui/Superprobe/SP_JF_Cy5_2024Sep4, /scratchdata1/Images2024/Aihui/Superprobe/SP_JF_Cy5_2024Sep4)

# %%
""" Generate Executable for entire dataset """
import os
base_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
processing_key = 'Processing_2024May28'
for dataset in sorted(os.listdir(base_path)):
    if not '_' in dataset:
        continue
    if not len([i for i in os.listdir(os.path.join(base_path,dataset)) if 'ybe23' in i]) > 0:
        continue
    if os.path.exists(os.path.join(base_path,dataset,processing_key)):
        continue
    # if 'PTZ' in dataset:
    #     continue
    if 'PTZ' in dataset:
        continue
    print(f"conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py {os.path.join(base_path,dataset)} > {os.path.join(base_path,dataset,'processing_nohup.out')} &")
    print(' ')

# %%
""" Generate Executable for each well """
import os
base_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
processing_key = 'Processing_2024May28'
for dataset in sorted(os.listdir(base_path)):
    if not '_' in dataset:
        continue
    if not len([i for i in os.listdir(os.path.join(base_path,dataset)) if 'ybe23' in i]) > 0:
        continue
    if os.path.exists(os.path.join(base_path,dataset,processing_key)):
        continue
    # if 'PTZ' in dataset:
    #     continue
    if 'PTZ' in dataset:
        continue
    wells = [i.split('.')[-1] for i in dataset.split('_') if '.' in i]
    for well in wells:
        print(f"conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py {os.path.join(base_path,dataset)} -w {well}> {os.path.join(base_path,dataset,'processing_nohup_'+well+'.out')} &")
        print(' ')

# %%
""" Check Processing Status """
import os
from dredFISH.Utils import fileu
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

processing_key = 'Processing_2024May28'
project_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
datasets = [i for i in os.listdir(project_path) if '_' in i]
status = {}
for dataset in sorted(datasets):
    processing_path = os.path.join(project_path,dataset,processing_key)
    if not os.path.exists(processing_path):
        continue
    status[dataset] = {}
    sections = [i for i in os.listdir(processing_path) if '-' in i]
    for section in sections:
        data_path = fileu.generate_filename(path=os.path.join(processing_path,section),hybe='',channel='',file_type='anndata')
        if os.path.exists(data_path):
            status[dataset][section] = True
        else:
            status[dataset][section] = False
total = 0
not_completed_datasets = []
completed_datasets = []
for dataset,dataset_status in status.items():
    completed = np.sum([value for section,value in dataset_status.items()])
    total+=completed
    not_completed = np.sum([value==False for section,value in dataset_status.items()])
    if not_completed > 0:
        not_completed_datasets.append(dataset)
        print(f"{completed} Completed Sections for \033[91m{dataset}\033[0m {not_completed}")
    else:
        completed_datasets.append(dataset)
        print(f"{completed} Completed Sections for \033[92m{dataset}\033[0m ")
print(f"{total} Completed Sections for All")
# Out:
# 24 Completed Sections for ASDM02_4.2.D_4.2.E_6.2.F_1.2.A_2.2.B_3.2.C_2024May20
# 23 Completed Sections for ASDM02_6.3.A_5.3.B_4.3.C_1.3.D_2.3.E_3.3.F_2024Jun10
# 24 Completed Sections for ASDM02_7.3.A_8.3.B_9.3.C_12.3.D_11.3.E_10.3.F_2024Jun10
# 24 Completed Sections for ASDM02_9.2.A_8.2.B_7.2.C_12.2.D_11.2.E_10.2.F_2024May20
# 20 Completed Sections for ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08
# 24 Completed Sections for ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08
# 24 Completed Sections for ASDM13_1.2.A_2.2.B_3.2.C_4.2.D_5.2.E_6.2.F_2024Jul17
# 24 Completed Sections for ASDM13_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul16
# 24 Completed Sections for ASDM14_1.3.A_2.3.B_3.3.C_4.1.D_5.3.E_12.3.F_2024Aug19
# 24 Completed Sections for ASDM14_6.1.A_7.1.B_8.1.C_9.1.D_10.1.E_11.2.F_2024Jul29
# 24 Completed Sections for ASDM15_1.2.A_2.2.B_3.2.C_4.3.D_5.2.E_12.2.F_2024Aug19
# 24 Completed Sections for ASDM15_6.2.A_7.2.B_8.2.C_9.2.D_10.2.E_11.2.F_2024Jul29
# 24 Completed Sections for GapFill_WTM07.12.3.A_WTM07.11.3.B_WTM01.4.1.C_WTF06.7.3.D_WTF04.12.2.E_ASDM13.12.1.F_2024Aug02
# 24 Completed Sections for MMSF01_6.3.A_5.3.B_4.3.C_3.3.F_2.3.E_1.3.D_2024Apr15
# 24 Completed Sections for MMSF02_1.1.A_2.1.B_3.1.C_4.1.D_5.1.E_6.2.F_2024Aug02
# 24 Completed Sections for MMSM01_1.1.A_2.1.B_3.1.C_4.1.F_5.1.E_6.1.D_2024Apr15
# 24 Completed Sections for WTF01_1.2.A_2.2.B_3.2.C_4.2.D_5.2.E_6.2.F_2024Apr08
# 24 Completed Sections for WTF04_4.1.D_5.1.E_6.1.F_1.1.A_2.1.B_3.1.C_2024Jun3
# 20 Completed Sections for WTF04_9.1.A_8.1.B_7.1.C_11.1.E_10.1.F_2024Jun3
# 24 Completed Sections for WTF05_6.3.A_7.3.B_8.3.C_9.3.D_10.3.E_11.3.F_2024Jun17
# 24 Completed Sections for WTF05_8.2.A_7.2.B_6.2.C_11.2.D_10.2.E_9.2.F_2024Jul02
# 24 Completed Sections for WTF06_1.1.A_2.1.B_3.1.C_4.1.D_5.1.E_12.1.F_2024Jul23
# 24 Completed Sections for WTF06_6.2.A_7.2.B_8.2.C_9.1.D_10.2.E_11.1.F_2024Jun17
# 24 Completed Sections for WTF11_1.2.A_2.2.B_3.2.C_4.2.D_5.2.E_12.2.F_2024Aug13
# 24 Completed Sections for WTF11_6.1.A_7.2.B_8.2.C_9.2.D_10.2.E_11.2.F_2024Aug07
# 24 Completed Sections for WTM01_3.2.A_2.2.B_1.2.C_6.2.D_5.2.E_4.2.F_2024Apr08
# 16 Completed Sections for WTM02_2.2.A_1.1.B_2.1.D_3.2.E_2024Apr01
# 16 Completed Sections for WTM02_3.1.A_2.3.B_3.3.D_1.2.E_2024Apr01
# 24 Completed Sections for WTM04_10.2.A_11.2.B_12.2.C_7.2.D_8.2.E_9.2.F_2024May13
# 24 Completed Sections for WTM04_3.2.D_2.2.E_1.2.F_6.2.A_5.2.B_4.2.C_2024May13
# 24 Completed Sections for WTM04_4.3.D_5.3.E_6.3.F_1.3.A_2.3.B_3.3.C_2024May28
# 24 Completed Sections for WTM04_9.3.A_8.3.B_7.3.C_12.3.D_11.3.E_10.3.F_2024May28
# 24 Completed Sections for WTM06_6.3.A_7.3.B_8.3.C_9.3.D_10.3.E_11.3.F_2024Jul02
# 22 Completed Sections for WTM06_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun17
# 24 Completed Sections for WTM07_1.1.A_2.1.B_3.1.C_4.1.D_5.1.E_12.1.F_2024Jul23
# 24 Completed Sections for WTM07_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun24
# 24 Completed Sections for WTM11_1.2.A_2.2.B_3.2.C_4.2.D_5.2.E_12.2.F_2024Aug13
# 24 Completed Sections for WTM11_6.2.A_7.2.B_8.2.C_9.2.D_10.2.E_11.2.F_2024Aug07
# 885 Completed Sections for All

# %%
""" Make Executable for not completed datasets """
import os
base_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
processing_key = 'Processing_2024May28'
for dataset in not_completed_datasets:
    print(f"conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py {os.path.join(base_path,dataset)} > {os.path.join(base_path,dataset,'processing_nohup.out')} &")
    print(' ')

# %%
""" Make Executable for not completed datasets per well """
import os
base_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
processing_key = 'Processing_2024May28'
for dataset in not_completed_datasets:
    wells = [i.split('.')[-1] for i in dataset.split('_') if '.' in i]
    for well in wells:
        print(f"conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py {os.path.join(base_path,dataset)} -w {well}> {os.path.join(base_path,dataset,'processing_nohup_'+well+'.out')} &")
        print(' ')

# %%
""" View Active Processing Logs """
import os
base_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
proccessing_name = 'Processing_2024May28'
for dataset in not_completed_datasets:#sorted(os.listdir(base_path)):
    # if 'ASD' in dataset.split('_')[0]:
    #     continue
    if not os.path.exists(os.path.join(base_path,dataset,proccessing_name)):
        continue
    for processing in os.listdir(os.path.join(base_path,dataset)):
        if 'processing' in processing.split('_')[0]:
            print(f"{dataset} \033[91m{processing}\033[0m")
            print(os.path.join(base_path,dataset,processing))
            print(' ')
            ! tail -10 {os.path.join(base_path,dataset,processing)}
            print(' ')

# %%
""" Check Processing Status """
import os
from dredFISH.Utils import fileu
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
Total = 0
not_completed_datasets = []
completed_datasets = []
processing_key = 'Processing_2024May28'
project_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
datasets = [i for i in os.listdir(project_path) if '_' in i]
status = {}
for dataset in sorted(datasets):
    processing_path = os.path.join(project_path,dataset,processing_key)
    if not os.path.exists(processing_path):
        continue
    status[dataset] = {}
    sections = [i for i in os.listdir(processing_path) if '-' in i]
    for section in sections:
        """ Check if processing is finished """
        data_path = fileu.generate_filename(path=os.path.join(processing_path,section),hybe='',channel='',file_type='anndata')
        if os.path.exists(data_path):
            """ Check if Registration is finished """
            registration_paths = [i for i in os.listdir(os.path.join(project_path,dataset)) if 'Registration' in i]
            registered = False
            for registration_path in registration_paths:
                if not section in os.listdir(os.path.join(project_path,dataset,registration_path)):
                    continue
                if os.path.exists(fileu.generate_filename(path=os.path.join(project_path,dataset,registration_path,section),hybe='',channel='Y',file_type='Model')):
                    registered = True
                    break
            if registered:
                status[dataset][section] = 'Registered'
            else:
                status[dataset][section] = 'Processed'
        else:
            status[dataset][section] = 'Not Processed'
        dataset_status = status[dataset]
    processed = np.sum([value=='Processed' for section,value in dataset_status.items()])
    registered = np.sum([value=='Registered' for section,value in dataset_status.items()])
    not_processed = np.sum([value=='Not Processed' for section,value in dataset_status.items()])
    total = 0
    total+=processed
    total+=registered
    Total+=total
    if not_processed > 0:
        not_completed_datasets.append(dataset)
        print(f"{total} Completed Sections for \033[91m{dataset}\033[0m {not_processed}")
    elif registered>0:
        completed_datasets.append(dataset)
        print(f"{total} Completed Sections for \033[92m{dataset}\033[0m ")
    else:
        completed_datasets.append(dataset)
        print(f"{total} Completed Sections for \033[93m{dataset}\033[0m ")
print(f"{Total} Completed Sections for All")
# Out:
# 24 Completed Sections for ASDM02_4.2.D_4.2.E_6.2.F_1.2.A_2.2.B_3.2.C_2024May20
# 23 Completed Sections for ASDM02_6.3.A_5.3.B_4.3.C_1.3.D_2.3.E_3.3.F_2024Jun10
# 24 Completed Sections for ASDM02_7.3.A_8.3.B_9.3.C_12.3.D_11.3.E_10.3.F_2024Jun10
# 24 Completed Sections for ASDM02_9.2.A_8.2.B_7.2.C_12.2.D_11.2.E_10.2.F_2024May20
# 20 Completed Sections for ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08
# 24 Completed Sections for ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08
# 24 Completed Sections for ASDM13_1.2.A_2.2.B_3.2.C_4.2.D_5.2.E_6.2.F_2024Jul17
# 24 Completed Sections for ASDM13_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul16
# 24 Completed Sections for ASDM14_1.3.A_2.3.B_3.3.C_4.1.D_5.3.E_12.3.F_2024Aug19
# 24 Completed Sections for ASDM14_6.1.A_7.1.B_8.1.C_9.1.D_10.1.E_11.2.F_2024Jul29
# 24 Completed Sections for ASDM15_1.2.A_2.2.B_3.2.C_4.3.D_5.2.E_12.2.F_2024Aug19
# 24 Completed Sections for ASDM15_6.2.A_7.2.B_8.2.C_9.2.D_10.2.E_11.2.F_2024Jul29
# 24 Completed Sections for GapFill_WTM07.12.3.A_WTM07.11.3.B_WTM01.4.1.C_WTF06.7.3.D_WTF04.12.2.E_ASDM13.12.1.F_2024Aug02
# 24 Completed Sections for MMSF01_6.3.A_5.3.B_4.3.C_3.3.F_2.3.E_1.3.D_2024Apr15
# 24 Completed Sections for MMSF02_1.1.A_2.1.B_3.1.C_4.1.D_5.1.E_6.2.F_2024Aug02
# 24 Completed Sections for MMSM01_1.1.A_2.1.B_3.1.C_4.1.F_5.1.E_6.1.D_2024Apr15
# 24 Completed Sections for WTF01_1.2.A_2.2.B_3.2.C_4.2.D_5.2.E_6.2.F_2024Apr08
# 24 Completed Sections for WTF04_4.1.D_5.1.E_6.1.F_1.1.A_2.1.B_3.1.C_2024Jun3
# 20 Completed Sections for WTF04_9.1.A_8.1.B_7.1.C_11.1.E_10.1.F_2024Jun3
# 24 Completed Sections for WTF05_6.3.A_7.3.B_8.3.C_9.3.D_10.3.E_11.3.F_2024Jun17
# 24 Completed Sections for WTF05_8.2.A_7.2.B_6.2.C_11.2.D_10.2.E_9.2.F_2024Jul02
# 24 Completed Sections for WTF06_1.1.A_2.1.B_3.1.C_4.1.D_5.1.E_12.1.F_2024Jul23
# 24 Completed Sections for WTF06_6.2.A_7.2.B_8.2.C_9.1.D_10.2.E_11.1.F_2024Jun17
# 24 Completed Sections for WTF11_1.2.A_2.2.B_3.2.C_4.2.D_5.2.E_12.2.F_2024Aug13
# 24 Completed Sections for WTF11_6.1.A_7.2.B_8.2.C_9.2.D_10.2.E_11.2.F_2024Aug07
# 24 Completed Sections for WTM01_3.2.A_2.2.B_1.2.C_6.2.D_5.2.E_4.2.F_2024Apr08
# 16 Completed Sections for WTM02_2.2.A_1.1.B_2.1.D_3.2.E_2024Apr01
# 16 Completed Sections for WTM02_3.1.A_2.3.B_3.3.D_1.2.E_2024Apr01
# 24 Completed Sections for WTM04_10.2.A_11.2.B_12.2.C_7.2.D_8.2.E_9.2.F_2024May13
# 24 Completed Sections for WTM04_3.2.D_2.2.E_1.2.F_6.2.A_5.2.B_4.2.C_2024May13
# 24 Completed Sections for WTM04_4.3.D_5.3.E_6.3.F_1.3.A_2.3.B_3.3.C_2024May28
# 24 Completed Sections for WTM04_9.3.A_8.3.B_7.3.C_12.3.D_11.3.E_10.3.F_2024May28
# 24 Completed Sections for WTM06_6.3.A_7.3.B_8.3.C_9.3.D_10.3.E_11.3.F_2024Jul02
# 22 Completed Sections for WTM06_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun17
# 24 Completed Sections for WTM07_1.1.A_2.1.B_3.1.C_4.1.D_5.1.E_12.1.F_2024Jul23
# 24 Completed Sections for WTM07_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun24
# 24 Completed Sections for WTM11_1.2.A_2.2.B_3.2.C_4.2.D_5.2.E_12.2.F_2024Aug13
# 24 Completed Sections for WTM11_6.2.A_7.2.B_8.2.C_9.2.D_10.2.E_11.2.F_2024Aug07
# 885 Completed Sections for All

# %%
animals = np.unique([i.split('_')[0] for i in completed_datasets if not 'GapFill' in i])
animals
# Out:
# array(['ASDM02', 'ASDM12', 'ASDM13', 'ASDM14', 'ASDM15', 'MMSF01',
#        'MMSF02', 'MMSM01', 'WTF01', 'WTF04', 'WTF05', 'WTF06', 'WTF11',
#        'WTM01', 'WTM02', 'WTM04', 'WTM06', 'WTM07', 'WTM11'], dtype='<U6')

# %%
animal = 'Tax'
analysis_path = '/scratchdata1/MouseBrainAtlases_V7'
if not os.path.exists(analysis_path):
    os.mkdir(analysis_path)
print(f"conda activate dredfish_3.9; nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py {animal} -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a {analysis_path} > {analysis_path}/execute_{animal}.log &")
print('  ')

for animal in animals:
    print(f"conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py {animal} -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a {analysis_path} > {analysis_path}/execute_{animal}.log &")
    print('  ')
# Out:
# conda activate dredfish_3.9; nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py Tax -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_Tax.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py ASDM02 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_ASDM02.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py ASDM12 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_ASDM12.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py ASDM13 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_ASDM13.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py ASDM14 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_ASDM14.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py ASDM15 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_ASDM15.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py MMSF01 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_MMSF01.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py MMSF02 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_MMSF02.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py MMSM01 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_MMSM01.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py WTF01 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_WTF01.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py WTF04 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_WTF04.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py WTF05 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_WTF05.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py WTF06 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_WTF06.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py WTF11 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_WTF11.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py WTM01 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_WTM01.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py WTM02 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_WTM02.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py WTM04 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_WTM04.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py WTM06 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_WTM06.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py WTM07 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_WTM07.log &
#
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py WTM11 -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a /scratchdata1/MouseBrainAtlases_V7 > /scratchdata1/MouseBrainAtlases_V7/execute_WTM11.log &

# %%
animal = 'Tax'
analysis_path = '/scratchdata1/MouseBrainAtlases_V7'
# if not os.path.exists(analysis_path):
#     os.mkdir(analysis_path)
# print(f"conda activate dredfish_3.9; nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py {animal} -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a {analysis_path} > {analysis_path}/execute_{animal}.log &")
# print('  ')
animals = ['ASDM02', 'ASDM12', 'ASDM13', 'ASDM14', 'ASDM15', 'MMSF01',
       'MMSF02', 'MMSM01', 'WTF01', 'WTF04', 'WTF05', 'WTF06', 'WTF11',
       'WTM01', 'WTM02', 'WTM04', 'WTM06', 'WTM07', 'WTM11']
for animal in animals:
    # print(animal)
    print('\n')
    print(f"\033[91m{animal}\033[0m")
    log = str(f"/scratchdata1/MouseBrainAtlases_V7/execute_{animal}.log")
    ! tail -10 {log}

    print('\n')
    print(f"\033[92m{animal}\033[0m")
    log = str(f"/scratchdata1/MouseBrainAtlases_V7/{animal}/tmg_log.txt")
    ! tail -10 {log}
    # print(f"conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py {animal} -p /scratchdata1/Images2024/Zach/MouseBrainAtlas -a {analysis_path} > {analysis_path}/execute_{animal}.log &")
    # print('  ')
# Out:
# ASDM02
# RS0384_cy5 Visualization: 90it [00:24,  3.61it/s]
# RS0406_cy5 Visualization: 90it [00:23,  3.75it/s]
# RS0451_cy5 Visualization: 90it [00:23,  3.85it/s]
# RS0548_cy5 Visualization: 90it [00:24,  3.65it/s]
# RS64.0_cy5 Visualization: 90it [00:26,  3.36it/s]
# RSN4287.0_cy5 Visualization: 90it [01:05,  1.37it/s]
# RSN1252.0_cy5 Visualization: 90it [00:23,  3.82it/s]
# RSN9535.0_cy5 Visualization: 90it [00:22,  4.01it/s]
# RS740.0_cy5 Visualization: 90it [00:23,  3.79it/s]
# RS810.0_cy5 Visualization: 90it [00:22,  3.95it/s]
#
#
# ASDM02
# 2024 September 05 09:08:07,716 SCALE INFO Updating Priors
# 2024 September 05 09:08:07,856 SCALE INFO Performing Supervised Harmonization
# 2024 September 05 09:08:07,856 SCALE INFO Creating Dendrogram
# 2024 September 05 09:23:04,711 SCALE INFO Remaking Priors
# 2024 September 05 09:23:17,597 SCALE INFO Harmonizing
# 2024 September 05 09:27:07,691 SCALE INFO Mapping labels to subclass
# 2024 September 05 09:27:07,716 SCALE INFO Determining Neighbors
# 2024 September 05 09:27:07,717 SCALE INFO Querying Reference tree
# 2024 September 05 09:37:57,341 Processing INFO saved
# 2024 September 05 09:37:58,208 Processing INFO Checking For Bad Sections
#
#
# ASDM12
# 2024 September 05 05:44:32 saved
# 2024 September 05 05:44:32 Loading Taxonomies
# 2024 September 05 05:44:35 Creating Merged Layer for Cell Labels
# 2024 September 05 05:55:43 Creating Merged Layer for Parcellation Labels
# 2024 September 05 05:55:48 Adding Type Information to Parcellation Labels
# 2024 September 05 05:56:21 saved
# 2024 September 05 05:56:21 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 05:57:41 saved
# 2024 September 05 05:57:41 Completed
# Analysis of ASDM12 complete
#
#
# ASDM12
# 2024 September 05 04:52:50,663 SCALE INFO Mapping labels to subclass
# 2024 September 05 04:52:50,689 SCALE INFO Determining Neighbors
# 2024 September 05 04:52:50,689 SCALE INFO Querying Reference tree
# 2024 September 05 05:00:22,801 Processing INFO saved
# 2024 September 05 05:00:23,764 Processing INFO Checking For Bad Sections
# 2024 September 05 05:55:48,613 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 05:56:21,512 Processing INFO saved
# 2024 September 05 05:56:21,513 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 05:57:41,37 Processing INFO saved
# 2024 September 05 05:57:41,38 Processing INFO Completed
#
#
# ASDM13
# 2024 September 05 07:33:06 saved
# 2024 September 05 07:33:06 Loading Taxonomies
# 2024 September 05 07:33:08 Creating Merged Layer for Cell Labels
# 2024 September 05 07:40:05 Creating Merged Layer for Parcellation Labels
# 2024 September 05 07:40:09 Adding Type Information to Parcellation Labels
# 2024 September 05 07:40:47 saved
# 2024 September 05 07:40:47 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 07:41:55 saved
# 2024 September 05 07:41:55 Completed
# Analysis of ASDM13 complete
#
#
# ASDM13
# 2024 September 05 06:43:04,794 SCALE INFO Mapping labels to subclass
# 2024 September 05 06:43:04,808 SCALE INFO Determining Neighbors
# 2024 September 05 06:43:04,809 SCALE INFO Querying Reference tree
# 2024 September 05 06:49:54,514 Processing INFO saved
# 2024 September 05 06:49:55,241 Processing INFO Checking For Bad Sections
# 2024 September 05 07:40:09,822 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 07:40:47,807 Processing INFO saved
# 2024 September 05 07:40:47,807 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 07:41:55,524 Processing INFO saved
# 2024 September 05 07:41:55,524 Processing INFO Completed
#
#
# ASDM14
# 2024 September 05 07:20:51 saved
# 2024 September 05 07:20:51 Loading Taxonomies
# 2024 September 05 07:20:52 Creating Merged Layer for Cell Labels
# 2024 September 05 07:31:42 Creating Merged Layer for Parcellation Labels
# 2024 September 05 07:31:52 Adding Type Information to Parcellation Labels
# 2024 September 05 07:32:28 saved
# 2024 September 05 07:32:28 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 07:34:01 saved
# 2024 September 05 07:34:01 Completed
# Analysis of ASDM14 complete
#
#
# ASDM14
# 2024 September 05 06:34:11,651 SCALE INFO Mapping labels to subclass
# 2024 September 05 06:34:11,661 SCALE INFO Determining Neighbors
# 2024 September 05 06:34:11,662 SCALE INFO Querying Reference tree
# 2024 September 05 06:41:09,689 Processing INFO saved
# 2024 September 05 06:41:10,437 Processing INFO Checking For Bad Sections
# 2024 September 05 07:31:52,329 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 07:32:28,692 Processing INFO saved
# 2024 September 05 07:32:28,692 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 07:34:01,848 Processing INFO saved
# 2024 September 05 07:34:01,849 Processing INFO Completed
#
#
# ASDM15
# 2024 September 05 04:55:56 saved
# 2024 September 05 04:55:56 Loading Taxonomies
# 2024 September 05 04:55:57 Creating Merged Layer for Cell Labels
# 2024 September 05 05:07:57 Creating Merged Layer for Parcellation Labels
# 2024 September 05 05:08:02 Adding Type Information to Parcellation Labels
# 2024 September 05 05:08:35 saved
# 2024 September 05 05:08:35 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 05:12:13 saved
# 2024 September 05 05:12:13 Completed
# Analysis of ASDM15 complete
#
#
# ASDM15
# 2024 September 05 04:13:49,818 SCALE INFO Mapping labels to subclass
# 2024 September 05 04:13:49,870 SCALE INFO Determining Neighbors
# 2024 September 05 04:13:49,870 SCALE INFO Querying Reference tree
# 2024 September 05 04:20:30,525 Processing INFO saved
# 2024 September 05 04:20:31,399 Processing INFO Checking For Bad Sections
# 2024 September 05 05:08:02,273 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 05:08:35,747 Processing INFO saved
# 2024 September 05 05:08:35,747 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 05:12:13,852 Processing INFO saved
# 2024 September 05 05:12:13,852 Processing INFO Completed
#
#
# MMSF01
# 2024 September 05 04:29:42 saved
# 2024 September 05 04:29:42 Loading Taxonomies
# 2024 September 05 04:29:43 Creating Merged Layer for Cell Labels
# 2024 September 05 04:42:16 Creating Merged Layer for Parcellation Labels
# 2024 September 05 04:42:22 Adding Type Information to Parcellation Labels
# 2024 September 05 04:42:52 saved
# 2024 September 05 04:42:52 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 04:43:50 saved
# 2024 September 05 04:43:50 Completed
# Analysis of MMSF01 complete
#
#
# MMSF01
# 2024 September 05 03:51:21,990 SCALE INFO Mapping labels to subclass
# 2024 September 05 03:51:22,31 SCALE INFO Determining Neighbors
# 2024 September 05 03:51:22,31 SCALE INFO Querying Reference tree
# 2024 September 05 03:57:43,841 Processing INFO saved
# 2024 September 05 03:57:44,745 Processing INFO Checking For Bad Sections
# 2024 September 05 04:42:22,160 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 04:42:52,492 Processing INFO saved
# 2024 September 05 04:42:52,492 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 04:43:50,515 Processing INFO saved
# 2024 September 05 04:43:50,515 Processing INFO Completed
#
#
# MMSF02
# 2024 September 05 03:13:39 saved
# 2024 September 05 03:13:39 Loading Taxonomies
# 2024 September 05 03:13:41 Creating Merged Layer for Cell Labels
# 2024 September 05 03:46:51 Creating Merged Layer for Parcellation Labels
# 2024 September 05 03:46:53 Adding Type Information to Parcellation Labels
# 2024 September 05 03:47:17 saved
# 2024 September 05 03:47:17 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 03:48:00 saved
# 2024 September 05 03:48:00 Completed
# Analysis of MMSF02 complete
#
#
# MMSF02
# 2024 September 05 02:28:37,543 SCALE INFO Mapping labels to subclass
# 2024 September 05 02:28:37,563 SCALE INFO Determining Neighbors
# 2024 September 05 02:28:37,563 SCALE INFO Querying Reference tree
# 2024 September 05 02:35:06,769 Processing INFO saved
# 2024 September 05 02:35:07,570 Processing INFO Checking For Bad Sections
# 2024 September 05 03:46:53,430 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 03:47:17,9 Processing INFO saved
# 2024 September 05 03:47:17,23 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 03:48:00,895 Processing INFO saved
# 2024 September 05 03:48:00,895 Processing INFO Completed
#
#
# MMSM01
# 2024 September 05 05:01:44 saved
# 2024 September 05 05:01:44 Loading Taxonomies
# 2024 September 05 05:01:47 Creating Merged Layer for Cell Labels
# 2024 September 05 05:36:49 Creating Merged Layer for Parcellation Labels
# 2024 September 05 05:36:58 Adding Type Information to Parcellation Labels
# 2024 September 05 05:37:38 saved
# 2024 September 05 05:37:38 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 05:40:47 saved
# 2024 September 05 05:40:47 Completed
# Analysis of MMSM01 complete
#
#
# MMSM01
# 2024 September 05 04:01:28,762 SCALE INFO Mapping labels to subclass
# 2024 September 05 04:01:28,821 SCALE INFO Determining Neighbors
# 2024 September 05 04:01:28,821 SCALE INFO Querying Reference tree
# 2024 September 05 04:09:25,71 Processing INFO saved
# 2024 September 05 04:09:26,187 Processing INFO Checking For Bad Sections
# 2024 September 05 05:36:58,334 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 05:37:38,453 Processing INFO saved
# 2024 September 05 05:37:38,454 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 05:40:47,664 Processing INFO saved
# 2024 September 05 05:40:47,665 Processing INFO Completed
#
#
# WTF01
# 2024 September 05 05:12:39 saved
# 2024 September 05 05:12:39 Loading Taxonomies
# 2024 September 05 05:12:42 Creating Merged Layer for Cell Labels
# 2024 September 05 05:50:44 Creating Merged Layer for Parcellation Labels
# 2024 September 05 05:50:48 Adding Type Information to Parcellation Labels
# 2024 September 05 05:51:19 saved
# 2024 September 05 05:51:19 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 05:52:26 saved
# 2024 September 05 05:52:26 Completed
# Analysis of WTF01 complete
#
#
# WTF01
# 2024 September 05 04:10:54,795 SCALE INFO Mapping labels to subclass
# 2024 September 05 04:10:54,831 SCALE INFO Determining Neighbors
# 2024 September 05 04:10:54,831 SCALE INFO Querying Reference tree
# 2024 September 05 04:21:52,691 Processing INFO saved
# 2024 September 05 04:21:53,448 Processing INFO Checking For Bad Sections
# 2024 September 05 05:50:48,287 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 05:51:19,103 Processing INFO saved
# 2024 September 05 05:51:19,104 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 05:52:26,276 Processing INFO saved
# 2024 September 05 05:52:26,277 Processing INFO Completed
#
#
# WTF04
# 2024 September 05 09:32:00 saved
# 2024 September 05 09:32:00 Loading Taxonomies
# 2024 September 05 09:32:04 Creating Merged Layer for Cell Labels
# 2024 September 05 10:17:34 Creating Merged Layer for Parcellation Labels
# 2024 September 05 10:17:47 Adding Type Information to Parcellation Labels
# 2024 September 05 10:18:51 saved
# 2024 September 05 10:18:51 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 10:20:52 saved
# 2024 September 05 10:20:52 Completed
# Analysis of WTF04 complete
#
#
# WTF04
# 2024 September 05 08:07:24,762 SCALE INFO Mapping labels to subclass
# 2024 September 05 08:07:24,777 SCALE INFO Determining Neighbors
# 2024 September 05 08:07:24,777 SCALE INFO Querying Reference tree
# 2024 September 05 08:17:58,272 Processing INFO saved
# 2024 September 05 08:17:59,25 Processing INFO Checking For Bad Sections
# 2024 September 05 10:17:47,775 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 10:18:51,826 Processing INFO saved
# 2024 September 05 10:18:51,827 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 10:20:52,440 Processing INFO saved
# 2024 September 05 10:20:52,441 Processing INFO Completed
#
#
# WTF05
# 2024 September 05 05:20:28 saved
# 2024 September 05 05:20:28 Loading Taxonomies
# 2024 September 05 05:20:29 Creating Merged Layer for Cell Labels
# 2024 September 05 05:50:49 Creating Merged Layer for Parcellation Labels
# 2024 September 05 05:50:51 Adding Type Information to Parcellation Labels
# 2024 September 05 05:51:10 saved
# 2024 September 05 05:51:10 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 05:51:40 saved
# 2024 September 05 05:51:40 Completed
# Analysis of WTF05 complete
#
#
# WTF05
# 2024 September 05 04:38:54,380 SCALE INFO Mapping labels to subclass
# 2024 September 05 04:38:54,386 SCALE INFO Determining Neighbors
# 2024 September 05 04:38:54,386 SCALE INFO Querying Reference tree
# 2024 September 05 04:44:39,58 Processing INFO saved
# 2024 September 05 04:44:39,867 Processing INFO Checking For Bad Sections
# 2024 September 05 05:50:51,112 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 05:51:10,853 Processing INFO saved
# 2024 September 05 05:51:10,867 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 05:51:40,726 Processing INFO saved
# 2024 September 05 05:51:40,727 Processing INFO Completed
#
#
# WTF06
# 2024 September 05 10:05:10 saved
# 2024 September 05 10:05:10 Loading Taxonomies
# 2024 September 05 10:05:14 Creating Merged Layer for Cell Labels
# 2024 September 05 10:24:02 Creating Merged Layer for Parcellation Labels
# 2024 September 05 10:24:08 Adding Type Information to Parcellation Labels
# 2024 September 05 10:24:50 saved
# 2024 September 05 10:24:50 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 10:26:18 saved
# 2024 September 05 10:26:18 Completed
# Analysis of WTF06 complete
#
#
# WTF06
# 2024 September 05 08:30:33,829 SCALE INFO Mapping labels to subclass
# 2024 September 05 08:30:33,842 SCALE INFO Determining Neighbors
# 2024 September 05 08:30:33,842 SCALE INFO Querying Reference tree
# 2024 September 05 08:41:13,53 Processing INFO saved
# 2024 September 05 08:41:14,311 Processing INFO Checking For Bad Sections
# 2024 September 05 10:24:08,859 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 10:24:50,271 Processing INFO saved
# 2024 September 05 10:24:50,272 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 10:26:18,31 Processing INFO saved
# 2024 September 05 10:26:18,31 Processing INFO Completed
#
#
# WTF11
# 2024 September 05 06:13:43 saved
# 2024 September 05 06:13:43 Loading Taxonomies
# 2024 September 05 06:13:45 Creating Merged Layer for Cell Labels
# 2024 September 05 06:23:07 Creating Merged Layer for Parcellation Labels
# 2024 September 05 06:23:14 Adding Type Information to Parcellation Labels
# 2024 September 05 06:23:48 saved
# 2024 September 05 06:23:48 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 06:25:04 saved
# 2024 September 05 06:25:04 Completed
# Analysis of WTF11 complete
#
#
# WTF11
# 2024 September 05 05:07:22,544 SCALE INFO Mapping labels to subclass
# 2024 September 05 05:07:22,561 SCALE INFO Determining Neighbors
# 2024 September 05 05:07:22,562 SCALE INFO Querying Reference tree
# 2024 September 05 05:16:15,918 Processing INFO saved
# 2024 September 05 05:16:16,686 Processing INFO Checking For Bad Sections
# 2024 September 05 06:23:14,112 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 06:23:48,977 Processing INFO saved
# 2024 September 05 06:23:48,978 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 06:25:04,966 Processing INFO saved
# 2024 September 05 06:25:04,967 Processing INFO Completed
#
#
# WTM01
# 2024 September 05 03:48:01 saved
# 2024 September 05 03:48:01 Loading Taxonomies
# 2024 September 05 03:48:03 Creating Merged Layer for Cell Labels
# 2024 September 05 04:00:08 Creating Merged Layer for Parcellation Labels
# 2024 September 05 04:00:11 Adding Type Information to Parcellation Labels
# 2024 September 05 04:00:46 saved
# 2024 September 05 04:00:46 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 04:02:07 saved
# 2024 September 05 04:02:07 Completed
# Analysis of WTM01 complete
#
#
# WTM01
# 2024 September 05 02:53:40,616 SCALE INFO Mapping labels to subclass
# 2024 September 05 02:53:40,645 SCALE INFO Determining Neighbors
# 2024 September 05 02:53:40,645 SCALE INFO Querying Reference tree
# 2024 September 05 03:02:03,571 Processing INFO saved
# 2024 September 05 03:02:04,258 Processing INFO Checking For Bad Sections
# 2024 September 05 04:00:11,685 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 04:00:46,332 Processing INFO saved
# 2024 September 05 04:00:46,333 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 04:02:07,241 Processing INFO saved
# 2024 September 05 04:02:07,241 Processing INFO Completed
#
#
# WTM02
# 2024 September 05 03:42:58 saved
# 2024 September 05 03:42:58 Loading Taxonomies
# 2024 September 05 03:43:00 Creating Merged Layer for Cell Labels
# 2024 September 05 03:59:02 Creating Merged Layer for Parcellation Labels
# 2024 September 05 03:59:06 Adding Type Information to Parcellation Labels
# 2024 September 05 03:59:36 saved
# 2024 September 05 03:59:36 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 04:00:35 saved
# 2024 September 05 04:00:35 Completed
# Analysis of WTM02 complete
#
#
# WTM02
# 2024 September 05 02:49:43,849 SCALE INFO Mapping labels to subclass
# 2024 September 05 02:49:43,886 SCALE INFO Determining Neighbors
# 2024 September 05 02:49:43,887 SCALE INFO Querying Reference tree
# 2024 September 05 02:57:30,922 Processing INFO saved
# 2024 September 05 02:57:31,660 Processing INFO Checking For Bad Sections
# 2024 September 05 03:59:06,360 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 03:59:36,258 Processing INFO saved
# 2024 September 05 03:59:36,258 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 04:00:35,682 Processing INFO saved
# 2024 September 05 04:00:35,683 Processing INFO Completed
#
#
# WTM04
#     obsm: 'XY'
#     layers: 'nuc_processed_vectors', 'nuc_raw', 'processed_vectors', 'raw', 'nuc_mask', 'normalized', 'classification_space', 'harmonized', 'imputed', 'zscored'
# 2024 September 05 09:52:10 saved
# 2024 September 05 09:52:11 Enforcing Order
# AnnData object with n_obs × n_vars = 6156736 × 18
#     obs: 'label', 'stage_x', 'stage_y', 'image_x', 'image_y', 'image_idx', 'size', 'section_index', 'dapi', 'sum', 'dataset', 'well', 'animal', 'processing', 'ccf_x', 'ccf_y', 'ccf_z', 'old_section_name', 'registration_path', 'section_name', 'Slice', 'in_large_comp', 'node_size', 'subclass', 'subclass_color', 'leiden', 'leiden_color', 'neuron', 'neuron_color', 'reference_neighbor_0', 'reference_neighbor_1', 'reference_neighbor_2', 'reference_neighbor_3', 'reference_neighbor_4', 'reference_neighbor_5', 'reference_neighbor_6', 'reference_neighbor_7', 'reference_neighbor_8', 'reference_neighbor_9', 'reference_neighbor_10', 'reference_neighbor_11', 'reference_neighbor_12', 'reference_neighbor_13', 'reference_neighbor_14', 'Correlation'
#     obsm: 'XY'
#     layers: 'nuc_processed_vectors', 'nuc_raw', 'processed_vectors', 'raw', 'nuc_mask', 'normalized', 'classification_space', 'harmonized', 'imputed', 'zscored'
# 2024 September 05 10:01:12 saved
# subclass Visualization: 92it [00:35,  2.62it/s]
#
#
# WTM04
# 2024 September 05 09:39:19,593 SCALE INFO Updating Priors
# 2024 September 05 09:39:19,645 SCALE INFO Performing Supervised Harmonization
# 2024 September 05 09:39:19,646 SCALE INFO Creating Dendrogram
# 2024 September 05 09:39:24,975 SCALE INFO Remaking Priors
# 2024 September 05 09:39:26,836 SCALE INFO Harmonizing
# 2024 September 05 09:40:35,276 SCALE INFO Mapping labels to subclass
# 2024 September 05 09:40:35,284 SCALE INFO Determining Neighbors
# 2024 September 05 09:40:35,284 SCALE INFO Querying Reference tree
# 2024 September 05 09:50:06,33 Processing INFO saved
# 2024 September 05 09:50:06,819 Processing INFO Checking For Bad Sections
#
#
# WTM06
# 2024 September 05 04:20:28 saved
# 2024 September 05 04:20:28 Loading Taxonomies
# 2024 September 05 04:20:29 Creating Merged Layer for Cell Labels
# 2024 September 05 04:26:25 Creating Merged Layer for Parcellation Labels
# 2024 September 05 04:26:27 Adding Type Information to Parcellation Labels
# 2024 September 05 04:26:47 saved
# 2024 September 05 04:26:47 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 04:27:17 saved
# 2024 September 05 04:27:17 Completed
# Analysis of WTM06 complete
#
#
# WTM06
# 2024 September 05 03:46:03,129 SCALE INFO Mapping labels to subclass
# 2024 September 05 03:46:03,138 SCALE INFO Determining Neighbors
# 2024 September 05 03:46:03,138 SCALE INFO Querying Reference tree
# 2024 September 05 03:50:22,850 Processing INFO saved
# 2024 September 05 03:50:23,753 Processing INFO Checking For Bad Sections
# 2024 September 05 04:26:27,595 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 04:26:47,915 Processing INFO saved
# 2024 September 05 04:26:47,915 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 04:27:17,624 Processing INFO saved
# 2024 September 05 04:27:17,625 Processing INFO Completed
#
#
# WTM07
# 2024 September 05 07:48:52 saved
# 2024 September 05 07:48:52 Loading Taxonomies
# 2024 September 05 07:48:54 Creating Merged Layer for Cell Labels
# 2024 September 05 07:55:05 Creating Merged Layer for Parcellation Labels
# 2024 September 05 07:55:10 Adding Type Information to Parcellation Labels
# 2024 September 05 07:55:42 saved
# 2024 September 05 07:55:42 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 07:56:44 saved
# 2024 September 05 07:56:44 Completed
# Analysis of WTM07 complete
#
#
# WTM07
# 2024 September 05 06:48:26,689 SCALE INFO Mapping labels to subclass
# 2024 September 05 06:48:26,709 SCALE INFO Determining Neighbors
# 2024 September 05 06:48:26,709 SCALE INFO Querying Reference tree
# 2024 September 05 06:55:05,172 Processing INFO saved
# 2024 September 05 06:55:05,778 Processing INFO Checking For Bad Sections
# 2024 September 05 07:55:10,213 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 07:55:42,764 Processing INFO saved
# 2024 September 05 07:55:42,764 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 07:56:44,100 Processing INFO saved
# 2024 September 05 07:56:44,101 Processing INFO Completed
#
#
# WTM11
# 2024 September 05 07:19:10 saved
# 2024 September 05 07:19:10 Loading Taxonomies
# 2024 September 05 07:19:12 Creating Merged Layer for Cell Labels
# 2024 September 05 07:26:08 Creating Merged Layer for Parcellation Labels
# 2024 September 05 07:26:14 Adding Type Information to Parcellation Labels
# 2024 September 05 07:26:50 saved
# 2024 September 05 07:26:50 Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 07:28:00 saved
# 2024 September 05 07:28:00 Completed
# Analysis of WTM11 complete
#
#
# WTM11
# 2024 September 05 06:15:56,491 SCALE INFO Mapping labels to subclass
# 2024 September 05 06:15:56,501 SCALE INFO Determining Neighbors
# 2024 September 05 06:15:56,501 SCALE INFO Querying Reference tree
# 2024 September 05 06:24:35,782 Processing INFO saved
# 2024 September 05 06:24:36,613 Processing INFO Checking For Bad Sections
# 2024 September 05 07:26:14,128 Processing INFO Adding Type Information to Parcellation Labels
# 2024 September 05 07:26:50,986 Processing INFO saved
# 2024 September 05 07:26:50,986 Processing INFO Creating Merged Layer for Higher Level Parcellations
# 2024 September 05 07:28:00,540 Processing INFO saved
# 2024 September 05 07:28:00,540 Processing INFO Completed

# %% [markdown]
# conda activate dredfish_3.9; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Analysis/execute.py RNA -p /scratchdata1/Images2024/Haley/dredfish -a /scratchdata1/MouseBrainAtlases_V6 > /scratchdata1/MouseBrainAtlases_V6/execute_RNA.log &

# %% [markdown]
# <!-- # base_path = '/scratchdata1/Images2024/Zach/'
# # def get_directory_size(path):
# #     """Recursively calculates the size of a directory and its contents in bytes."""
# #     total_size = 0
# #     for dirpath, dirnames, filenames in os.walk(path):
# #         for filename in filenames:
# #             filepath = os.path.join(dirpath, filename)
# #             total_size += os.path.getsize(filepath)
# #     return total_size
# # import shutil
# # storage_directories = [i for i in os.listdir('/') if 'data' in i[-4:]]
# # for storage in storage_directories:
# #     total_savings = 0
# #     # print(' ')
# #     # print(storage)
# #     # print(' ')
# #     for year in os.listdir(os.path.join('/',storage)):
# #         if not 'Images' in year:
# #             continue
# #         for user in ['Zach','Gaby','gaby','Thomas','Haley','Sofia']:
# #             base_path = os.path.join('/',storage,year,user)
# #             if not os.path.exists(base_path):
# #                 continue
# #             """ check if i have permission"""
# #             if not os.access(os.path.join(base_path), os.W_OK):
# #                 continue
# #             for projects in os.listdir(base_path):
# #                 if not os.path.isdir(os.path.join(base_path,projects)):
# #                     continue
# #                 """ check if i have permission"""
# #                 if not os.access(os.path.join(base_path,projects), os.W_OK):
# #                     continue
# #                 for dataset in os.listdir(os.path.join(base_path,projects)):
# #                     if not os.path.isdir(os.path.join(base_path,projects,dataset)):
# #                         continue
# #                     """ check if i have permission"""
# #                     if not os.access(os.path.join(base_path,projects,dataset), os.W_OK):
# #                         continue
# #                     for acq in os.listdir(os.path.join(base_path,projects,dataset)):
# #                         if not 'acq' in acq:
# #                             continue
# #                         if not os.path.isdir(os.path.join(base_path,projects,dataset,acq)):
# #                             continue
# #                         """ check if i have permission"""
# #                         if not os.access(os.path.join(base_path,projects,dataset,acq), os.W_OK):
# #                             continue
# #                         for pos in os.listdir(os.path.join(base_path,projects,dataset,acq)):
# #                             # if 'Metadata' in pos:
# #                                 # os.rename(os.path.join(base_path,projects,dataset,acq,pos), os.path.join(base_path,projects,dataset,'Ignore_'+pos))
# #                             if not os.path.isdir(os.path.join(base_path,projects,dataset,acq,pos)):
# #                                 continue
# #                             """ check if i have permission"""
# #                             if not os.access(os.path.join(base_path,projects,dataset,acq,pos), os.W_OK):
# #                                 continue
# #                             """ get size of directory """
# #                             size = get_directory_size(os.path.join(base_path,projects,dataset,acq,pos))
# #                             total_savings += size
# #                             # print(f"{total_savings/(1024**3):.2f}",end="\r" )
# #     print(f"{storage} {total_savings/(1024**3):.2f}") -->
