# %%
import os
import datetime

storage_directories = [i for i in os.listdir('/') if 'data' in i[-4:]]
destination = 'scratchdata1'
if not os.path.exists(os.path.join('/',destination)):
    print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.mkdir({os.path.join('/',destination)}, mode=0o775)")
    os.mkdir(os.path.join('/',destination), mode=0o775)
for storage in storage_directories:
    for year in os.listdir(os.path.join('/',storage)):
        if 'External' in year:
            if not os.path.exists(os.path.join('/',destination,year)):
                print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.symlink({os.path.join('/',storage,year)}, {os.path.join('/',destination,year)})")
                os.symlink(os.path.join('/',storage,year), os.path.join('/',destination,year))
                continue
        if not 'Images' in year:
            continue
        if not os.path.exists(os.path.join('/',destination,year)):
            print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.mkdir({os.path.join('/',destination,year)}, mode=0o775)")
            os.mkdir(os.path.join('/',destination,year), mode=0o775)
        for user in os.listdir(os.path.join('/',storage,year)):
            if not os.path.isdir(os.path.join('/',storage,year,user)):
                continue
            if not os.path.exists(os.path.join('/',destination,year,user)):
                print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.mkdir({os.path.join('/',destination,year,user)}, mode=0o775)")
                os.mkdir(os.path.join('/',destination,year,user), mode=0o775)
            try:
                for project in os.listdir(os.path.join('/',storage,year,user)):
                    if not os.path.isdir(os.path.join('/',storage,year,user,project)):
                        continue
                    if not os.path.exists(os.path.join('/',destination,year,user,project)):
                        print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.mkdir({os.path.join('/',destination,year,user,project)}, mode=0o775)")
                        os.mkdir(os.path.join('/',destination,year,user,project), mode=0o775)
                    try:
                        for dataset in os.listdir(os.path.join('/',storage,year,user,project)):
                            if not os.path.isdir(os.path.join('/',storage,year,user,project,dataset)):
                                continue
                            if not os.path.exists(os.path.join('/',destination,year,user,project,dataset)):
                                print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')} os.symlink({os.path.join('/',storage,year,user,project,dataset)}, {os.path.join('/',destination,year,user,project,dataset)})")
                                os.symlink(os.path.join('/',storage,year,user,project,dataset), os.path.join('/',destination,year,user,project,dataset))
                    except:
                        print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')}  Failed {os.path.join('/',storage,year,user,project,dataset)}")
                        pass
            except:
                print(f" {datetime.datetime.now().strftime('%Y%b%d %H:%M:%S')}  Failed {os.path.join('/',storage,year,user,project)}")
                pass
# Out:
#  2024Jul19 12:45:30  Failed /greendata/Images2019/Zach/TNF_3T3/z-stacks.zip
#  2024Jul19 12:45:58  Failed /greendata/Images2021/Gaby/NN_2021Jul01/uncleared_1
#  2024Jul19 12:46:05  Failed /bluedata/Images2023/test_folder_permission/Elegans
#  2024Jul19 12:46:05  Failed /bluedata/Images2023/Zach/thick_dredFISH/smFISH_older.D_newer.E_2023Feb24

# %%
import os
base_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
processing_key = 'Processing_2024May28'
for dataset in sorted(os.listdir(base_path)):
    if not '_' in dataset:
        continue
    if not len([i for i in os.listdir(os.path.join(base_path,dataset)) if 'ybe23' in i]) > 0:
        continue
    if os.path.exists(os.path.join(base_path,dataset,processing_key)):
        continue
    # if 'PTZ' in dataset:
    #     continue
    if 'PTZ' in dataset:
        continue
    print(f"conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py {os.path.join(base_path,dataset)} > {os.path.join(base_path,dataset,'processing_nohup.out')} &")
    print(' ')

# %%
import os
base_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
processing_key = 'Processing_2024May28'
for dataset in sorted(os.listdir(base_path)):
    if not '_' in dataset:
        continue
    if not len([i for i in os.listdir(os.path.join(base_path,dataset)) if 'ybe23' in i]) > 0:
        continue
    if os.path.exists(os.path.join(base_path,dataset,processing_key)):
        continue
    # if 'PTZ' in dataset:
    #     continue
    if 'PTZ' in dataset:
        continue
    wells = [i.split('.')[-1] for i in dataset.split('_') if '.' in i]
    for well in wells:
        print(f"conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py {os.path.join(base_path,dataset)} -w {well}> {os.path.join(base_path,dataset,'processing_nohup_'+well+'.out')} &")
        print(' ')

# %%
import os
from dredFISH.Utils import fileu
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

processing_key = 'Processing_2024May28'
project_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
datasets = [i for i in os.listdir(project_path) if '_' in i]
status = {}
for dataset in sorted(datasets):
    processing_path = os.path.join(project_path,dataset,processing_key)
    if not os.path.exists(processing_path):
        continue
    status[dataset] = {}
    sections = [i for i in os.listdir(processing_path) if '-' in i]
    for section in sections:
        data_path = fileu.generate_filename(path=os.path.join(processing_path,section),hybe='',channel='',file_type='anndata')
        if os.path.exists(data_path):
            status[dataset][section] = True
        else:
            status[dataset][section] = False
total = 0
not_completed_datasets = []
completed_datasets = []
for dataset,dataset_status in status.items():
    completed = np.sum([value for section,value in dataset_status.items()])
    total+=completed
    not_completed = np.sum([value==False for section,value in dataset_status.items()])
    if not_completed > 0:
        not_completed_datasets.append(dataset)
        print(f"{completed} Completed Sections for \033[91m{dataset}\033[0m {not_completed}")
    else:
        completed_datasets.append(dataset)
        print(f"{completed} Completed Sections for \033[92m{dataset}\033[0m ")
print(f"{total} Completed Sections for All")
# Out:
# 24 Completed Sections for ASDM02_4.2.D_4.2.E_6.2.F_1.2.A_2.2.B_3.2.C_2024May20
# 23 Completed Sections for ASDM02_6.3.A_5.3.B_4.3.C_1.3.D_2.3.E_3.3.F_2024Jun10
# 24 Completed Sections for ASDM02_7.3.A_8.3.B_9.3.C_12.3.D_11.3.E_10.3.F_2024Jun10
# 24 Completed Sections for ASDM02_9.2.A_8.2.B_7.2.C_12.2.D_11.2.E_10.2.F_2024May20
# 19 Completed Sections for ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 1
# 22 Completed Sections for ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 2
# 24 Completed Sections for MMSF01_6.3.A_5.3.B_4.3.C_3.3.F_2.3.E_1.3.D_2024Apr15
# 24 Completed Sections for MMSM01_1.1.A_2.1.B_3.1.C_4.1.F_5.1.E_6.1.D_2024Apr15
# 24 Completed Sections for WTF01_1.2.A_2.2.B_3.2.C_4.2.D_5.2.E_6.2.F_2024Apr08
# 24 Completed Sections for WTF04_4.1.D_5.1.E_6.1.F_1.1.A_2.1.B_3.1.C_2024Jun3
# 20 Completed Sections for WTF04_9.1.A_8.1.B_7.1.C_11.1.E_10.1.F_2024Jun3
# 24 Completed Sections for WTF05_6.3.A_7.3.B_8.3.C_9.3.D_10.3.E_11.3.F_2024Jun17
# 0.0 Completed Sections for WTF05_8.2.A_7.2.B_6.2.C_11.2.D_10.2.E_9.2.F_2024Jul02
# 24 Completed Sections for WTF06_6.2.A_7.2.B_8.2.C_9.1.D_10.2.E_11.1.F_2024Jun17
# 24 Completed Sections for WTM01_3.2.A_2.2.B_1.2.C_6.2.D_5.2.E_4.2.F_2024Apr08
# 16 Completed Sections for WTM02_2.2.A_1.1.B_2.1.D_3.2.E_2024Apr01
# 16 Completed Sections for WTM02_3.1.A_2.3.B_3.3.D_1.2.E_2024Apr01
# 24 Completed Sections for WTM04_10.2.A_11.2.B_12.2.C_7.2.D_8.2.E_9.2.F_2024May13
# 24 Completed Sections for WTM04_3.2.D_2.2.E_1.2.F_6.2.A_5.2.B_4.2.C_2024May13
# 24 Completed Sections for WTM04_4.3.D_5.3.E_6.3.F_1.3.A_2.3.B_3.3.C_2024May28
# 24 Completed Sections for WTM04_9.3.A_8.3.B_7.3.C_12.3.D_11.3.E_10.3.F_2024May28
# 24 Completed Sections for WTM06_6.3.A_7.3.B_8.3.C_9.3.D_10.3.E_11.3.F_2024Jul02
# 12 Completed Sections for WTM06_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun17
# 24 Completed Sections for WTM07_8.1.A_7.1.B_6.1.C_11.1.D_10.1.E_9.1.F_2024Jun24
# 512.0 Completed Sections for All

# %%
import os
base_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
processing_key = 'Processing_2024May28'
for dataset in not_completed_datasets:
    print(f"conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py {os.path.join(base_path,dataset)} > {os.path.join(base_path,dataset,'processing_nohup.out')} &")
    print(' ')
# Out:
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 > /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup.out &
#
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 > /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup.out &

# %%
import os
base_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
processing_key = 'Processing_2024May28'
for dataset in not_completed_datasets:
    wells = [i.split('.')[-1] for i in dataset.split('_') if '.' in i]
    for well in wells:
        print(f"conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py {os.path.join(base_path,dataset)} -w {well}> {os.path.join(base_path,dataset,'processing_nohup_'+well+'.out')} &")
        print(' ')
# Out:
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 -w A> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_A.out &
#
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 -w B> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_B.out &
#
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 -w D> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_D.out &
#
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 -w E> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_E.out &
#
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 -w F> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_F.out &
#
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 -w A> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_A.out &
#
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 -w B> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_B.out &
#
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 -w C> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_C.out &
#
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 -w D> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_D.out &
#
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 -w E> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_E.out &
#
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 -w F> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_F.out &

# %% [markdown]
# <!-- ssh orange
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 -w A> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_A.out &
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 -w E> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_E.out &
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 -w B> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_B.out &
#
# ssh blue
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 -w B> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_B.out &
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 -w F> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_F.out &
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 -w C> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_C.out &
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 -w E> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_E.out &
#
# ssh purple
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 -w D> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_D.out &
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 -w A> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_A.out &
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 -w D> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_D.out &
# conda activate dredfish_3.9 ; nice -n 10 nohup python -W ignore /home/zach/PythonRepos/dredFISH/dredFISH/Processing/execute.py /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 -w F> /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_F.out &
#   -->

# %%
import os
base_path = '/scratchdata1/Images2024/Zach/MouseBrainAtlas/'
proccessing_name = 'Processing_2024May28'
for dataset in not_completed_datasets:#sorted(os.listdir(base_path)):
    # if 'ASD' in dataset.split('_')[0]:
    #     continue
    if not os.path.exists(os.path.join(base_path,dataset,proccessing_name)):
        continue
    for processing in os.listdir(os.path.join(base_path,dataset)):
        if 'processing' in processing.split('_')[0]:
            print(f"{dataset} \033[91m{processing}\033[0m")
            print(os.path.join(base_path,dataset,processing))
            print(' ')
            ! tail -10 {os.path.join(base_path,dataset,processing)}
            print(' ')
# Out:
# ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 processing_nohup_F.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_F.out
#
# 2024 July 19 11:32:44 Stitching Hybe9_123_FarRed
# 2024 July 19 11:34:24 Detected Hybe24_33 as hybe24's Acquisition
# 2024 July 19 11:34:24 Detected Strip24_28 as Hybe24_33's Background
# 2024 July 19 11:34:45 Found Existing hybe24 Stitched
# 2024 July 19 11:34:45 Detected Hybe8_103 as hybe8's Acquisition
# 2024 July 19 11:34:45 Detected Strip8_98 as Hybe8_103's Background
# 2024 July 19 11:34:49 Loading FF and Constant For entire Round for Hybe8 FarRed
# 2024 July 19 11:34:49 Loading FF and Constant For entire Round for Strip8 FarRed
# 2024 July 19 11:34:50 Loading FF and Constant For entire Round for Hybe8 DeepBlue
# 2024 July 19 11:34:51 Loading FF and Constant For entire Round for Strip8 DeepBlue
#
# ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 processing_nohup.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup.out
#
# 2024 July 18 11:57:15 Loading FF and Constant For entire Round for Strip11 DeepBlue
# 2024 July 18 11:57:25 Processing Hybe11_154_FarRed
# 2024 July 18 12:01:54 Registering Hybe11_154_FarRed
# 2024 July 18 12:01:55 Stitching Hybe11_154_FarRed
# 2024 July 18 12:02:14 Detected Hybe1_114 as hybe1's Acquisition
# 2024 July 18 12:02:14 Detected Strip1_109 as Hybe1_114's Background
# 2024 July 18 12:02:17 Loading FF and Constant For entire Round for Hybe1 FarRed
# 2024 July 18 12:02:17 Loading FF and Constant For entire Round for Strip1 FarRed
# 2024 July 18 12:02:17 Loading FF and Constant For entire Round for Hybe1 DeepBlue
# 2024 July 18 12:02:17 Loading FF and Constant For entire Round for Strip1 DeepBlue
#
# ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 processing_nohup_E.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_E.out
#
# ... storing 'section_index' as categorical
# ... storing 'dataset' as categorical
# ... storing 'well' as categorical
# ... storing 'channel' as categorical
# 2024 July 19 04:49:28 Generating Raw Figure
# 2024 July 19 04:49:44 Generating Norm Figure
# 2024 July 19 04:50:00 Generating Dapi Figure
# 2024 July 19 04:50:15 Generating Louvain Figure
# 2024 July 19 04:50:59 Removing Temporary Files
# Completed
#
# ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 processing_nohup_B.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_B.out
#
# 2024 July 18 14:52:22 Processing Section WellB-Section4
# 2024 July 18 14:52:22 Making Scratch Path
# 2024 July 18 14:52:22 Loading Metadata
# 2024 July 18 14:52:26 detected PurpleScope as the device used
# {'fishdata': 'Processing_2024May28', 'hard_overwrite': False, 'use_scratch': False, 'pixel_size': 0.428, 'jitter_channel': 'FarRed', 'jitter_correction': False, 'bin': 2, 'stitch_raw': False, 'stitch_rotate': 0, 'stitch_flipud': False, 'stitch_fliplr': True, 'register_stitch_reference': True, 'segment_gpu': False, 'max_registration_shift': 200, 'QC_pixel_size': 2, 'diameter': 8, 'nucstain_channel': 'DeepBlue', 'nucstain_acq': 'hybe24', 'total_channel': 'FarRed', 'total_acq': 'all_max', 'outpath': '/greendata/GeneralStorage/Data/dredFISH/', 'n_pixels': [1224, 1024], 'highpass_function': 'rolling_ball', 'highpass_sigma': 25, 'highpass_smooth_function': 'median', 'highpass_smooth': 3, 'strip': True, 'model_types': ['total'], 'dapi_thresh': 200, 'background_estimate_iters': 0, 'stain_correction': False, 'stain_correction_downsample': 10, 'stain_correction_kernel': 1000, 'overlap': 0.02, 'fileu_version': 2, 'overlap_correction': False, 'ncpu': 5, 'set_min_zero': False, 'metric': 'median', 'microscope_parameters': 'microscope_parameters', 'imaging_batch': 'hybe', 'post_strip_process': False, 'acq_FF': False, 'acq_constant': False, 'use_FF': True, 'use_constant': True, 'fit_FF': False, 'fit_constant': False, 'clip_FF': False, 'clip_constant': False, 'FF_n_cpu': 1, 'constant_poly_degrees': 5, 'FF_poly_degrees': 5, 'smooth_FF': True, 'smooth_constant': True, 'constant_smooth_function': 'spline_min', 'constant_smooth_sigma': '32|34', 'FF_smooth_function': 'spline', 'FF_smooth_sigma': '32|34', 'post_processing_constant': False, 'process_img_before_FF': False, 'debug': False, 'config_overwrite': True, 'overwrite': False, 'segment_overwrite': False, 'vector_overwrite': False, 'overwrite_report': False, 'overwrite_louvain': False, 'scratch_path_base': '/scratchdata2/Processing_tmp', 'bitmap': [('RS0095_cy5', 'hybe1', 'FarRed'), ('RS0175_cy5', 'hybe3', 'FarRed'), ('RS0332_cy5', 'hybe6', 'FarRed'), ('RSN2336.0_cy5', 'hybe8', 'FarRed'), ('RSN1807.0_cy5', 'hybe9', 'FarRed'), ('RS0384_cy5', 'hybe10', 'FarRed'), ('RS0406_cy5', 'hybe11', 'FarRed'), ('RS0451_cy5', 'hybe12', 'FarRed'), ('RS0548_cy5', 'hybe14', 'FarRed'), ('RS64.0_cy5', 'hybe15', 'FarRed'), ('RSN4287.0_cy5', 'hybe16', 'FarRed'), ('RSN1252.0_cy5', 'hybe17', 'FarRed'), ('RSN9535.0_cy5', 'hybe18', 'FarRed'), ('RS740.0_cy5', 'hybe23', 'FarRed'), ('RS810.0_cy5', 'hybe24', 'FarRed'), ('RS458122_cy5', 'hybe21', 'FarRed'), ('RS0083_SS_Cy5', 'hybe5', 'FarRed'), ('RS0255_SS_Cy5', 'hybe20', 'FarRed')], 'path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/Processing_2024May28/WellB-Section4', 'metadata_path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08', 'well_path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/Processing_2024May28/WellB', 'scratch_path': '/scratchdata2/Processing_tmp/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/Processing_2024May28/WellB-Section4', 'dataset': 'ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08', 'section': 'WellB-Section4', 'well': 'WellB', 'scope': 'PurpleScope', 'process_pixel_size': 0.856, 'segment_diameter': 9.345794392523365, 'border': 1024, 'ratio': 0.428, 'pytorch_dtype': torch.float32, 'numpy_dtype': <class 'numpy.float32'>}
# 2024 July 18 14:52:29 247 Positions Found
# 2024 July 18 14:52:29 Attempting To Load Data
# 2024 July 18 14:52:31 Existing Data Found
# 2024 July 18 14:52:32 Removing Temporary Files
# Completed
#
# ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 processing_nohup_D.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_D.out
#
# 2024 July 18 14:26:12 Processing Section WellD-Section4
# 2024 July 18 14:26:12 Making Scratch Path
# 2024 July 18 14:26:12 Loading Metadata
# 2024 July 18 14:26:17 detected PurpleScope as the device used
# {'fishdata': 'Processing_2024May28', 'hard_overwrite': False, 'use_scratch': False, 'pixel_size': 0.428, 'jitter_channel': 'FarRed', 'jitter_correction': False, 'bin': 2, 'stitch_raw': False, 'stitch_rotate': 0, 'stitch_flipud': False, 'stitch_fliplr': True, 'register_stitch_reference': True, 'segment_gpu': False, 'max_registration_shift': 200, 'QC_pixel_size': 2, 'diameter': 8, 'nucstain_channel': 'DeepBlue', 'nucstain_acq': 'hybe24', 'total_channel': 'FarRed', 'total_acq': 'all_max', 'outpath': '/greendata/GeneralStorage/Data/dredFISH/', 'n_pixels': [1224, 1024], 'highpass_function': 'rolling_ball', 'highpass_sigma': 25, 'highpass_smooth_function': 'median', 'highpass_smooth': 3, 'strip': True, 'model_types': ['total'], 'dapi_thresh': 200, 'background_estimate_iters': 0, 'stain_correction': False, 'stain_correction_downsample': 10, 'stain_correction_kernel': 1000, 'overlap': 0.02, 'fileu_version': 2, 'overlap_correction': False, 'ncpu': 5, 'set_min_zero': False, 'metric': 'median', 'microscope_parameters': 'microscope_parameters', 'imaging_batch': 'hybe', 'post_strip_process': False, 'acq_FF': False, 'acq_constant': False, 'use_FF': True, 'use_constant': True, 'fit_FF': False, 'fit_constant': False, 'clip_FF': False, 'clip_constant': False, 'FF_n_cpu': 1, 'constant_poly_degrees': 5, 'FF_poly_degrees': 5, 'smooth_FF': True, 'smooth_constant': True, 'constant_smooth_function': 'spline_min', 'constant_smooth_sigma': '32|34', 'FF_smooth_function': 'spline', 'FF_smooth_sigma': '32|34', 'post_processing_constant': False, 'process_img_before_FF': False, 'debug': False, 'config_overwrite': True, 'overwrite': False, 'segment_overwrite': False, 'vector_overwrite': False, 'overwrite_report': False, 'overwrite_louvain': False, 'scratch_path_base': '/scratchdata2/Processing_tmp', 'bitmap': [('RS0095_cy5', 'hybe1', 'FarRed'), ('RS0175_cy5', 'hybe3', 'FarRed'), ('RS0332_cy5', 'hybe6', 'FarRed'), ('RSN2336.0_cy5', 'hybe8', 'FarRed'), ('RSN1807.0_cy5', 'hybe9', 'FarRed'), ('RS0384_cy5', 'hybe10', 'FarRed'), ('RS0406_cy5', 'hybe11', 'FarRed'), ('RS0451_cy5', 'hybe12', 'FarRed'), ('RS0548_cy5', 'hybe14', 'FarRed'), ('RS64.0_cy5', 'hybe15', 'FarRed'), ('RSN4287.0_cy5', 'hybe16', 'FarRed'), ('RSN1252.0_cy5', 'hybe17', 'FarRed'), ('RSN9535.0_cy5', 'hybe18', 'FarRed'), ('RS740.0_cy5', 'hybe23', 'FarRed'), ('RS810.0_cy5', 'hybe24', 'FarRed'), ('RS458122_cy5', 'hybe21', 'FarRed'), ('RS0083_SS_Cy5', 'hybe5', 'FarRed'), ('RS0255_SS_Cy5', 'hybe20', 'FarRed')], 'path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/Processing_2024May28/WellD-Section4', 'metadata_path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08', 'well_path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/Processing_2024May28/WellD', 'scratch_path': '/scratchdata2/Processing_tmp/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/Processing_2024May28/WellD-Section4', 'dataset': 'ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08', 'section': 'WellD-Section4', 'well': 'WellD', 'scope': 'PurpleScope', 'process_pixel_size': 0.856, 'segment_diameter': 9.345794392523365, 'border': 1024, 'ratio': 0.428, 'pytorch_dtype': torch.float32, 'numpy_dtype': <class 'numpy.float32'>}
# 2024 July 18 14:26:19 293 Positions Found
# 2024 July 18 14:26:19 Attempting To Load Data
# 2024 July 18 14:26:21 Existing Data Found
# 2024 July 18 14:26:21 Removing Temporary Files
# Completed
#
# ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08 processing_nohup_A.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/processing_nohup_A.out
#
# 2024 July 18 14:23:21 Processing Section WellA-Section4
# 2024 July 18 14:23:21 Making Scratch Path
# 2024 July 18 14:23:22 Loading Metadata
# 2024 July 18 14:23:25 detected PurpleScope as the device used
# {'fishdata': 'Processing_2024May28', 'hard_overwrite': False, 'use_scratch': False, 'pixel_size': 0.428, 'jitter_channel': 'FarRed', 'jitter_correction': False, 'bin': 2, 'stitch_raw': False, 'stitch_rotate': 0, 'stitch_flipud': False, 'stitch_fliplr': True, 'register_stitch_reference': True, 'segment_gpu': False, 'max_registration_shift': 200, 'QC_pixel_size': 2, 'diameter': 8, 'nucstain_channel': 'DeepBlue', 'nucstain_acq': 'hybe24', 'total_channel': 'FarRed', 'total_acq': 'all_max', 'outpath': '/greendata/GeneralStorage/Data/dredFISH/', 'n_pixels': [1224, 1024], 'highpass_function': 'rolling_ball', 'highpass_sigma': 25, 'highpass_smooth_function': 'median', 'highpass_smooth': 3, 'strip': True, 'model_types': ['total'], 'dapi_thresh': 200, 'background_estimate_iters': 0, 'stain_correction': False, 'stain_correction_downsample': 10, 'stain_correction_kernel': 1000, 'overlap': 0.02, 'fileu_version': 2, 'overlap_correction': False, 'ncpu': 5, 'set_min_zero': False, 'metric': 'median', 'microscope_parameters': 'microscope_parameters', 'imaging_batch': 'hybe', 'post_strip_process': False, 'acq_FF': False, 'acq_constant': False, 'use_FF': True, 'use_constant': True, 'fit_FF': False, 'fit_constant': False, 'clip_FF': False, 'clip_constant': False, 'FF_n_cpu': 1, 'constant_poly_degrees': 5, 'FF_poly_degrees': 5, 'smooth_FF': True, 'smooth_constant': True, 'constant_smooth_function': 'spline_min', 'constant_smooth_sigma': '32|34', 'FF_smooth_function': 'spline', 'FF_smooth_sigma': '32|34', 'post_processing_constant': False, 'process_img_before_FF': False, 'debug': False, 'config_overwrite': True, 'overwrite': False, 'segment_overwrite': False, 'vector_overwrite': False, 'overwrite_report': False, 'overwrite_louvain': False, 'scratch_path_base': '/scratchdata2/Processing_tmp', 'bitmap': [('RS0095_cy5', 'hybe1', 'FarRed'), ('RS0175_cy5', 'hybe3', 'FarRed'), ('RS0332_cy5', 'hybe6', 'FarRed'), ('RSN2336.0_cy5', 'hybe8', 'FarRed'), ('RSN1807.0_cy5', 'hybe9', 'FarRed'), ('RS0384_cy5', 'hybe10', 'FarRed'), ('RS0406_cy5', 'hybe11', 'FarRed'), ('RS0451_cy5', 'hybe12', 'FarRed'), ('RS0548_cy5', 'hybe14', 'FarRed'), ('RS64.0_cy5', 'hybe15', 'FarRed'), ('RSN4287.0_cy5', 'hybe16', 'FarRed'), ('RSN1252.0_cy5', 'hybe17', 'FarRed'), ('RSN9535.0_cy5', 'hybe18', 'FarRed'), ('RS740.0_cy5', 'hybe23', 'FarRed'), ('RS810.0_cy5', 'hybe24', 'FarRed'), ('RS458122_cy5', 'hybe21', 'FarRed'), ('RS0083_SS_Cy5', 'hybe5', 'FarRed'), ('RS0255_SS_Cy5', 'hybe20', 'FarRed')], 'path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/Processing_2024May28/WellA-Section4', 'metadata_path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08', 'well_path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/Processing_2024May28/WellA', 'scratch_path': '/scratchdata2/Processing_tmp/ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08/Processing_2024May28/WellA-Section4', 'dataset': 'ASDM12_3.2.A_2.2.B_6.2.D_5.2.E_4.2.F_2024Jul08', 'section': 'WellA-Section4', 'well': 'WellA', 'scope': 'PurpleScope', 'process_pixel_size': 0.856, 'segment_diameter': 9.345794392523365, 'border': 1024, 'ratio': 0.428, 'pytorch_dtype': torch.float32, 'numpy_dtype': <class 'numpy.float32'>}
# 2024 July 18 14:23:28 258 Positions Found
# 2024 July 18 14:23:29 Attempting To Load Data
# 2024 July 18 14:23:32 Existing Data Found
# 2024 July 18 14:23:32 Removing Temporary Files
# Completed
#
# ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 processing_nohup_F.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_F.out
#
# ... storing 'section_index' as categorical
# ... storing 'dataset' as categorical
# ... storing 'well' as categorical
# ... storing 'channel' as categorical
# 2024 July 19 06:39:02 Generating Raw Figure
# 2024 July 19 06:39:23 Generating Norm Figure
# 2024 July 19 06:39:46 Generating Dapi Figure
# 2024 July 19 06:40:06 Generating Louvain Figure
# 2024 July 19 06:41:41 Removing Temporary Files
# Completed
#
# ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 processing_nohup.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup.out
#
# 2024 July 18 14:14:55 Loading FF and Constant For entire Round for Strip18 DeepBlue
# 2024 July 18 14:15:05 Processing Hybe18_27_FarRed
# 2024 July 18 14:18:56 Registering Hybe18_27_FarRed
# 2024 July 18 14:18:57 Stitching Hybe18_27_FarRed
# 2024 July 18 14:19:04 Detected Hybe21_51 as hybe21's Acquisition
# 2024 July 18 14:19:04 Detected Strip21_45 as Hybe21_51's Background
# 2024 July 18 14:19:07 Loading FF and Constant For entire Round for Hybe21 FarRed
# 2024 July 18 14:19:07 Loading FF and Constant For entire Round for Strip21 FarRed
# 2024 July 18 14:19:07 Loading FF and Constant For entire Round for Hybe21 DeepBlue
# 2024 July 18 14:19:08 Loading FF and Constant For entire Round for Strip21 DeepBlue
#
# ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 processing_nohup_E.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_E.out
#
# 2024 July 19 11:28:01 Loading FF and Constant For entire Round for Strip1 DeepBlue
# 2024 July 19 11:28:06 Processing Hybe1_137_FarRed
# 2024 July 19 11:30:16 Registering Hybe1_137_FarRed
# 2024 July 19 11:30:17 Stitching Hybe1_137_FarRed
# 2024 July 19 11:32:06 Detected Hybe23_224 as hybe23's Acquisition
# 2024 July 19 11:32:06 Detected Strip23_218 as Hybe23_224's Background
# 2024 July 19 11:32:09 Loading FF and Constant For entire Round for Hybe23 FarRed
# 2024 July 19 11:32:09 Loading FF and Constant For entire Round for Strip23 FarRed
# 2024 July 19 11:32:09 Loading FF and Constant For entire Round for Hybe23 DeepBlue
# 2024 July 19 11:32:09 Loading FF and Constant For entire Round for Strip23 DeepBlue
#
# ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 processing_nohup_C.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_C.out
#
# ... storing 'section_index' as categorical
# ... storing 'dataset' as categorical
# ... storing 'well' as categorical
# ... storing 'channel' as categorical
# 2024 July 18 22:43:10 Generating Raw Figure
# 2024 July 18 22:43:46 Generating Norm Figure
# 2024 July 18 22:44:28 Generating Dapi Figure
# 2024 July 18 22:45:05 Generating Louvain Figure
# 2024 July 18 22:54:29 Removing Temporary Files
# Completed
#
# ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 processing_nohup_B.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_B.out
#
# 2024 July 18 14:24:17 Processing Section WellB-Section4
# 2024 July 18 14:24:17 Making Scratch Path
# 2024 July 18 14:24:20 Loading Metadata
# 2024 July 18 14:24:24 detected OrangeScope as the device used
# {'fishdata': 'Processing_2024May28', 'hard_overwrite': False, 'use_scratch': False, 'pixel_size': 0.49, 'jitter_channel': '', 'jitter_correction': False, 'bin': 2, 'stitch_raw': False, 'stitch_rotate': 0, 'stitch_flipud': False, 'stitch_fliplr': True, 'register_stitch_reference': True, 'segment_gpu': False, 'max_registration_shift': 200, 'QC_pixel_size': 2, 'diameter': 8, 'nucstain_channel': 'DeepBlue', 'nucstain_acq': 'hybe24', 'total_channel': 'FarRed', 'total_acq': 'all_max', 'outpath': '/greendata/GeneralStorage/Data/dredFISH/', 'n_pixels': [1224, 1024], 'highpass_function': 'rolling_ball', 'highpass_sigma': 25, 'highpass_smooth_function': 'median', 'highpass_smooth': 3, 'strip': True, 'model_types': ['total'], 'dapi_thresh': 200, 'background_estimate_iters': 0, 'stain_correction': False, 'stain_correction_downsample': 10, 'stain_correction_kernel': 1000, 'overlap': 0.02, 'fileu_version': 2, 'overlap_correction': False, 'ncpu': 5, 'set_min_zero': False, 'metric': 'median', 'microscope_parameters': 'microscope_parameters', 'imaging_batch': 'hybe', 'post_strip_process': False, 'acq_FF': False, 'acq_constant': False, 'use_FF': True, 'use_constant': True, 'fit_FF': False, 'fit_constant': False, 'clip_FF': False, 'clip_constant': False, 'FF_n_cpu': 1, 'constant_poly_degrees': 5, 'FF_poly_degrees': 5, 'smooth_FF': True, 'smooth_constant': True, 'constant_smooth_function': 'spline_min', 'constant_smooth_sigma': '32|34', 'FF_smooth_function': 'spline', 'FF_smooth_sigma': '32|34', 'post_processing_constant': False, 'process_img_before_FF': False, 'debug': False, 'config_overwrite': True, 'overwrite': False, 'segment_overwrite': False, 'vector_overwrite': False, 'overwrite_report': False, 'overwrite_louvain': False, 'scratch_path_base': '/scratchdata2/Processing_tmp', 'bitmap': [('RS0095_cy5', 'hybe1', 'FarRed'), ('RS0175_cy5', 'hybe3', 'FarRed'), ('RS0332_cy5', 'hybe6', 'FarRed'), ('RSN2336.0_cy5', 'hybe8', 'FarRed'), ('RSN1807.0_cy5', 'hybe9', 'FarRed'), ('RS0384_cy5', 'hybe10', 'FarRed'), ('RS0406_cy5', 'hybe11', 'FarRed'), ('RS0451_cy5', 'hybe12', 'FarRed'), ('RS0548_cy5', 'hybe14', 'FarRed'), ('RS64.0_cy5', 'hybe15', 'FarRed'), ('RSN4287.0_cy5', 'hybe16', 'FarRed'), ('RSN1252.0_cy5', 'hybe17', 'FarRed'), ('RSN9535.0_cy5', 'hybe18', 'FarRed'), ('RS740.0_cy5', 'hybe23', 'FarRed'), ('RS810.0_cy5', 'hybe24', 'FarRed'), ('RS458122_cy5', 'hybe21', 'FarRed'), ('RS0083_SS_Cy5', 'hybe5', 'FarRed'), ('RS0255_SS_Cy5', 'hybe20', 'FarRed')], 'path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/Processing_2024May28/WellB-Section4', 'metadata_path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08', 'well_path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/Processing_2024May28/WellB', 'scratch_path': '/scratchdata2/Processing_tmp/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/Processing_2024May28/WellB-Section4', 'dataset': 'ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08', 'section': 'WellB-Section4', 'well': 'WellB', 'scope': 'OrangeScope', 'process_pixel_size': 0.98, 'segment_diameter': 8.16326530612245, 'border': 1024, 'ratio': 0.49, 'pytorch_dtype': torch.float32, 'numpy_dtype': <class 'numpy.float32'>}
# 2024 July 18 14:24:26 254 Positions Found
# 2024 July 18 14:24:26 Attempting To Load Data
# 2024 July 18 14:24:31 Existing Data Found
# 2024 July 18 14:24:33 Removing Temporary Files
# Completed
#
# ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 processing_nohup_D.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_D.out
#
# 2024 July 19 10:22:12 Loading FF and Constant For entire Round for Strip14 DeepBlue
# 2024 July 19 10:22:19 Processing Hybe14_114_FarRed
# 2024 July 19 10:25:38 Registering Hybe14_114_FarRed
# 2024 July 19 10:25:38 Stitching Hybe14_114_FarRed
# 2024 July 19 10:25:47 Detected Hybe18_30 as hybe18's Acquisition
# 2024 July 19 10:25:47 Detected Strip18_24 as Hybe18_30's Background
# 2024 July 19 10:25:49 Loading FF and Constant For entire Round for Hybe18 FarRed
# 2024 July 19 10:25:50 Loading FF and Constant For entire Round for Strip18 FarRed
# 2024 July 19 10:25:50 Loading FF and Constant For entire Round for Hybe18 DeepBlue
# 2024 July 19 10:25:50 Loading FF and Constant For entire Round for Strip18 DeepBlue
#
# ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08 processing_nohup_A.out
# /scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/processing_nohup_A.out
#
# 2024 July 18 14:26:13 Processing Section WellA-Section4
# 2024 July 18 14:26:13 Making Scratch Path
# 2024 July 18 14:26:13 Loading Metadata
# 2024 July 18 14:26:18 detected OrangeScope as the device used
# {'fishdata': 'Processing_2024May28', 'hard_overwrite': False, 'use_scratch': False, 'pixel_size': 0.49, 'jitter_channel': '', 'jitter_correction': False, 'bin': 2, 'stitch_raw': False, 'stitch_rotate': 0, 'stitch_flipud': False, 'stitch_fliplr': True, 'register_stitch_reference': True, 'segment_gpu': False, 'max_registration_shift': 200, 'QC_pixel_size': 2, 'diameter': 8, 'nucstain_channel': 'DeepBlue', 'nucstain_acq': 'hybe24', 'total_channel': 'FarRed', 'total_acq': 'all_max', 'outpath': '/greendata/GeneralStorage/Data/dredFISH/', 'n_pixels': [1224, 1024], 'highpass_function': 'rolling_ball', 'highpass_sigma': 25, 'highpass_smooth_function': 'median', 'highpass_smooth': 3, 'strip': True, 'model_types': ['total'], 'dapi_thresh': 200, 'background_estimate_iters': 0, 'stain_correction': False, 'stain_correction_downsample': 10, 'stain_correction_kernel': 1000, 'overlap': 0.02, 'fileu_version': 2, 'overlap_correction': False, 'ncpu': 5, 'set_min_zero': False, 'metric': 'median', 'microscope_parameters': 'microscope_parameters', 'imaging_batch': 'hybe', 'post_strip_process': False, 'acq_FF': False, 'acq_constant': False, 'use_FF': True, 'use_constant': True, 'fit_FF': False, 'fit_constant': False, 'clip_FF': False, 'clip_constant': False, 'FF_n_cpu': 1, 'constant_poly_degrees': 5, 'FF_poly_degrees': 5, 'smooth_FF': True, 'smooth_constant': True, 'constant_smooth_function': 'spline_min', 'constant_smooth_sigma': '32|34', 'FF_smooth_function': 'spline', 'FF_smooth_sigma': '32|34', 'post_processing_constant': False, 'process_img_before_FF': False, 'debug': False, 'config_overwrite': True, 'overwrite': False, 'segment_overwrite': False, 'vector_overwrite': False, 'overwrite_report': False, 'overwrite_louvain': False, 'scratch_path_base': '/scratchdata2/Processing_tmp', 'bitmap': [('RS0095_cy5', 'hybe1', 'FarRed'), ('RS0175_cy5', 'hybe3', 'FarRed'), ('RS0332_cy5', 'hybe6', 'FarRed'), ('RSN2336.0_cy5', 'hybe8', 'FarRed'), ('RSN1807.0_cy5', 'hybe9', 'FarRed'), ('RS0384_cy5', 'hybe10', 'FarRed'), ('RS0406_cy5', 'hybe11', 'FarRed'), ('RS0451_cy5', 'hybe12', 'FarRed'), ('RS0548_cy5', 'hybe14', 'FarRed'), ('RS64.0_cy5', 'hybe15', 'FarRed'), ('RSN4287.0_cy5', 'hybe16', 'FarRed'), ('RSN1252.0_cy5', 'hybe17', 'FarRed'), ('RSN9535.0_cy5', 'hybe18', 'FarRed'), ('RS740.0_cy5', 'hybe23', 'FarRed'), ('RS810.0_cy5', 'hybe24', 'FarRed'), ('RS458122_cy5', 'hybe21', 'FarRed'), ('RS0083_SS_Cy5', 'hybe5', 'FarRed'), ('RS0255_SS_Cy5', 'hybe20', 'FarRed')], 'path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/Processing_2024May28/WellA-Section4', 'metadata_path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08', 'well_path': '/scratchdata1/Images2024/Zach/MouseBrainAtlas/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/Processing_2024May28/WellA', 'scratch_path': '/scratchdata2/Processing_tmp/ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08/Processing_2024May28/WellA-Section4', 'dataset': 'ASDM12_7.2.A_8.2.B_9.2.C_10.2.D_11.2.E_12.2.F_2024Jul08', 'section': 'WellA-Section4', 'well': 'WellA', 'scope': 'OrangeScope', 'process_pixel_size': 0.98, 'segment_diameter': 8.16326530612245, 'border': 1024, 'ratio': 0.49, 'pytorch_dtype': torch.float32, 'numpy_dtype': <class 'numpy.float32'>}
# 2024 July 18 14:26:20 226 Positions Found
# 2024 July 18 14:26:20 Attempting To Load Data
# 2024 July 18 14:26:23 Existing Data Found
# 2024 July 18 14:26:24 Removing Temporary Files
# Completed

# %%
# base_path = '/scratchdata1/Images2024/Zach/'
# def get_directory_size(path):
#     """Recursively calculates the size of a directory and its contents in bytes."""
#     total_size = 0
#     for dirpath, dirnames, filenames in os.walk(path):
#         for filename in filenames:
#             filepath = os.path.join(dirpath, filename)
#             total_size += os.path.getsize(filepath)
#     return total_size
# import shutil
# storage_directories = [i for i in os.listdir('/') if 'data' in i[-4:]]
# for storage in storage_directories:
#     total_savings = 0
#     # print(' ')
#     # print(storage)
#     # print(' ')
#     for year in os.listdir(os.path.join('/',storage)):
#         if not 'Images' in year:
#             continue
#         for user in ['Zach','Gaby','gaby','Thomas','Haley','Sofia']:
#             base_path = os.path.join('/',storage,year,user)
#             if not os.path.exists(base_path):
#                 continue
#             """ check if i have permission"""
#             if not os.access(os.path.join(base_path), os.W_OK):
#                 continue
#             for projects in os.listdir(base_path):
#                 if not os.path.isdir(os.path.join(base_path,projects)):
#                     continue
#                 """ check if i have permission"""
#                 if not os.access(os.path.join(base_path,projects), os.W_OK):
#                     continue
#                 for dataset in os.listdir(os.path.join(base_path,projects)):
#                     if not os.path.isdir(os.path.join(base_path,projects,dataset)):
#                         continue
#                     """ check if i have permission"""
#                     if not os.access(os.path.join(base_path,projects,dataset), os.W_OK):
#                         continue
#                     for acq in os.listdir(os.path.join(base_path,projects,dataset)):
#                         if not 'acq' in acq:
#                             continue
#                         if not os.path.isdir(os.path.join(base_path,projects,dataset,acq)):
#                             continue
#                         """ check if i have permission"""
#                         if not os.access(os.path.join(base_path,projects,dataset,acq), os.W_OK):
#                             continue
#                         for pos in os.listdir(os.path.join(base_path,projects,dataset,acq)):
#                             # if 'Metadata' in pos:
#                                 # os.rename(os.path.join(base_path,projects,dataset,acq,pos), os.path.join(base_path,projects,dataset,'Ignore_'+pos))
#                             if not os.path.isdir(os.path.join(base_path,projects,dataset,acq,pos)):
#                                 continue
#                             """ check if i have permission"""
#                             if not os.access(os.path.join(base_path,projects,dataset,acq,pos), os.W_OK):
#                                 continue
#                             """ get size of directory """
#                             size = get_directory_size(os.path.join(base_path,projects,dataset,acq,pos))
#                             total_savings += size
#                             # print(f"{total_savings/(1024**3):.2f}",end="\r" )
#     print(f"{storage} {total_savings/(1024**3):.2f}")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
