# %% [markdown]
# Imports:

# %%
import numpy as np 

import matplotlib.pyplot as plt 

from sklearn.preprocessing import normalize

from dredFISH.Analysis.TissueGraph import *
from dredFISH.Analysis.Taxonomy import *

from MERFISH_Objects.FISHData import *

# %% [markdown]
# Load data

# %%
base_path = '/bigstore/Images2021/gaby/dredFISH/DPNMF_PolyA_2021Nov19/'
dataset = 'DPNMF_PolyA_2021Nov19'
fishdata = FISHData(os.path.join(base_path,'fishdata'))
data = fishdata.load_data('h5ad',dataset=dataset)
data.obs_names_make_unique()

data.X = data.layers['total_vectors']
data = data[np.isnan(data.X.max(1))==False]

data.X = data.X/data.obs['total_signal'][:,None]
data.X = data.X - np.array([np.percentile(data.X[:,i],25) for i in range(data.X.shape[1])])
data.X = data.X / np.array([np.percentile(data.X[:,i],75) for i in range(data.X.shape[1])])
data.X = normalize(data.X)

XY = np.asarray([data.obs['stage_y'], data.obs['stage_x']])
XY = np.transpose(XY)
data.obsm['stage'] = XY
# Out:
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# /tmp/ipykernel_2569507/2703933735.py:10: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   data.X = data.X/data.obs['total_signal'][:,None]

# %% [markdown]
# Build spatial graph

# %%
TG = TissueGraph()
TG.BuildSpatialGraph(XY)

# %% [markdown]
# Create a optimal taxonomy within the TissueGraph object

# %%
TG.TX.RecursiveLeidenWithTissueGraphCondEntropy(data.X,TG,metric = 'euclidean')
# Out:
# Build similarity graph
# calculation took: 29.19
# Calling initial optimization
#
#  Func-count     x          f(x)          Procedure
#     1        11.5208     -7.55092        initial
#     2        18.5792     -7.29269        golden
#     3        7.15843     -7.71946        golden
#     4        4.46235     -7.42183        golden
#     5        8.42466     -7.69415        parabolic
#     6        6.13196     -7.58975        parabolic
#     7        7.63498     -7.64779        parabolic
#     8        6.76635      -7.6632        golden
#     9        7.34046     -7.71931        golden
#    10        7.22713     -7.59856        parabolic
#    11         7.1551     -7.69995        parabolic
#    12        7.18467     -7.70534        golden
#    13        7.16845     -7.76134        golden
#    14        7.17465     -7.57041        golden
#    15        7.16463     -7.70995        golden
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# calculation took: 123.40
# Initial entropy was: 7.761336930695665 number of evals: 15
# Initial types found: 104
# descending the tree
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 0 into optimal parts, entropy 7.677725899297837
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 1 into optimal parts, entropy 7.677969502917226
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 2 into optimal parts, entropy 7.670975173861541
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 3 into optimal parts, entropy 7.68266613758038
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 4 into optimal parts, entropy 7.673814409515572
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 5 into optimal parts, entropy 7.69134971609667
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 6 into optimal parts, entropy 7.698467278453124
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 7 into optimal parts, entropy 7.672936088795191
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 8 into optimal parts, entropy 7.6683487593204465
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 92 into optimal parts, entropy 7.679453647042239
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 93 into optimal parts, entropy 7.670160962033232
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 94 into optimal parts, entropy 7.67786855674267
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 95 into optimal parts, entropy 7.716989353996704
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 96 into optimal parts, entropy 7.679181403277959
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 97 into optimal parts, entropy 7.679489053177113
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 98 into optimal parts, entropy 7.679489053177113
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 99 into optimal parts, entropy 7.70114176109907
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 100 into optimal parts, entropy 7.709377188274476
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 101 into optimal parts, entropy 7.685505022693624
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 102 into optimal parts, entropy 7.686433446604534
#
# Optimization terminated successfully;
# The returned value satisfies the termination criteria
# (using xtol =  0.01 )
# split groun 103 into optimal parts, entropy 7.679489053177113

# %%
from collections import Counter
Counter(TG.Type)
# Out:
# Counter({'0': 553,
#          '3': 1061,
#          '4': 854,
#          '5': 1718,
#          '7': 489,
#          '8': 1272,
#          '12': 1224,
#          '13': 1024,
#          '14': 671,
#          '17': 1203,
#          '18': 547,
#          '20': 747,
#          '21': 966,
#          '22': 548,
#          '9': 1006,
#          '23': 467,
#          '16': 1375,
#          '24': 931,
#          '26': 729,
#          '28': 1259,
#          '27': 1080,
#          '15': 781,
#          '2': 916,
#          '10': 1259,
#          '34': 1503,
#          '36': 1474,
#          '37': 1490,
#          '29': 983,
#          '1': 1115,
#          '19': 1265,
#          '41': 501,
#          '25': 418,
#          '11': 667,
#          '43': 549,
#          '33': 1469,
#          '47': 659,
#          '48': 627,
#          '46': 745,
#          '31': 523,
#          '44': 1116,
#          '50': 620,
#          '51': 948,
#          '52': 1320,
#          '53': 534,
#          '54': 1554,
#          '55': 1271,
#          '56': 1390,
#          '6': 790,
#          '58': 1164,
#          '59': 878,
#          '60': 1462,
#          '38': 665,
#          '64': 1041,
#          '65': 1161,
#          '66': 963,
#          '67': 765,
#          '70': 1049,
#          '30': 1499,
#          '71': 1062,
#          '72': 1528,
#          '73': 783,
#          '74': 1406,
#          '40': 1158,
#          '75': 996,
#          '42': 925,
#          '76': 434,
#          '77': 527,
#          '68': 1221,
#          '80': 775,
#          '69': 1038,
#          '49': 475,
#          '81': 774,
#          '63': 1274,
#          '82': 1703,
#          '62': 1494,
#          '83': 962,
#          '84': 1070,
#          '85': 1286,
#          '45': 1010,
#          '79': 1533,
#          '87': 533,
#          '88': 751,
#          '89': 1367,
#          '78': 1513,
#          '90': 179,
#          '91': 1128,
#          '93': 255,
#          '57': 941,
#          '39': 945,
#          '94': 549,
#          '61': 931,
#          '95': 1351,
#          '96': 884,
#          '86': 173,
#          '35': 766,
#          '97': 461,
#          '98': 691,
#          '99': 916,
#          '100': 1139,
#          '101': 571,
#          '92': 16,
#          '32': 37,
#          '102': 793,
#          '103': 604})
