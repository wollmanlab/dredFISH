# %%
import pynndescent
import numpy as np

# %%
xy = np.random.randn(100,2)
xy2 = np.random.randn(10,2)

# %%
a = pynndescent.NNDescent(xy, 
                      metric='euclidean', 
                      n_neighbors=30)

# %%
a.query(xy2)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Input In [11], in <module>
# ----> 1 a.query(xy2)
#
# File ~/anaconda3/envs/routine/lib/python3.10/site-packages/pynndescent/pynndescent_.py:1595, in NNDescent.query(self, query_data, k, epsilon)
#    1564 """Query the training graph_data for the k nearest neighbors
#    1565
#    1566 Parameters
#    (...)
#    1592     training graph_data.
#    1593 """
#    1594 if not hasattr(self, "_search_graph"):
# -> 1595     self._init_search_graph()
#    1597 if not self._is_sparse:
#    1598     # Standard case
#    1599     if not hasattr(self, "_search_function"):
#
# File ~/anaconda3/envs/routine/lib/python3.10/site-packages/pynndescent/pynndescent_.py:967, in NNDescent._init_search_graph(self)
#     961     self._search_forest = [
#     962         convert_tree_format(tree, self._raw_data.shape[0])
# ...
