# %%
from dredFISH.Analysis.TissueGraph import *
from dredFISH.Visualization.Viz import *

import matplotlib.pyplot as plt 
import colorcet as cc

# %%
TMG = TissueMultiGraph('/home/jperrie/Documents/dredFISH/dredFISH/Analysis/Notebooks/TMG_example.pkl')

# %%
mat, _ = TMG.get_raster(2)

# %%
plt.figure(figsize=(13, 13))
plt.imshow(mat, cmap=cc.cm.rainbow)
plt.xticks([], [])
plt.yticks([], [])
plt.show()

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
TOOLS="pan,wheel_zoom,reset"
p = figure(tools=TOOLS, width=600, height=600, min_border=10, min_border_left=50,
           toolbar_location="above", x_axis_location=None, y_axis_location=None,
           tooltips=[("value", "@image")])
p.x_range.range_padding = p.y_range.range_padding = 0
p.image(image=[mat], x=0, y=0, dw=10, dh=10, palette=cc.rainbow, level="image")
# Out:
# GlyphRenderer(id='1194', ...)

# %%
show(p)
