# %%
from allensdk.core.reference_space_cache import ReferenceSpaceCache
import matplotlib.pyplot as plt
import numpy as np
# from fish_helpers import *
reference_space_key = 'annotation/ccf_2017'#'annotation/ccf_2017' #'average_template' #'ara_nissl'
resolution = 10 
rspc = ReferenceSpaceCache(resolution, reference_space_key, manifest='manifest.json')
rsp = rspc.get_reference_space()
plt.imshow(rsp.get_slice_image(0, 7300), interpolation='none')
plt.show()

# %%
rsp.annotation.shape
# Out:
# (1320, 800, 1140)

# %%
for z in np.linspace(0,rsp.annotation.shape[0]-1,50):
    z = int(z)
    img = rsp.annotation[z,:,:].copy()
    plt.figure(figsize=[15,10])
    plt.title(z)
    plt.imshow(img, cmap='jet',vmin=np.percentile(img.ravel(),5),vmax=np.percentile(img.ravel(),95))
    plt.colorbar()
    plt.show()
